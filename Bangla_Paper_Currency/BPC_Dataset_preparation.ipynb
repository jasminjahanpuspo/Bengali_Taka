# %% [markdown]
# <a href="https://colab.research.google.com/github/jasminjahanpuspo/Bengali_Taka/blob/main/Bangla_Paper_Currency/BPC_Dataset_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Step 1: Setup Environment

# %% [markdown]
# ##### 🔹 Mount Google Drive
# *   Access datasets stored in your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### 🔹 Import Required Libraries
# *   First: Load all necessary libraries for image processing, data handling, and visualization.
# *   Second: Load TensorFlow, Keras, and layers for building CNN models.

# %%
# -------------------- Libraries for Data Handling -------------------- #
import numpy as np              # Numerical operations and arrays
import pandas as pd             # Data manipulation and analysis
import os                       # File and directory operations
import glob as gb               # File pattern matching (e.g., get all image paths)

# -------------------- Libraries for Image Processing ---------------- #
import cv2                      # OpenCV for image reading, processing, and augmentation

# -------------------- Libraries for Visualization ------------------ #
import matplotlib.pyplot as plt # Plotting graphs and images
import seaborn as sns           # Advanced visualizations (heatmaps, pairplots)
# %matplotlib inline
import matplotlib

from PIL import Image
import random
import math

import shutil
from tqdm import tqdm

from PIL import Image
from scipy.ndimage import gaussian_filter

# %%
# -------------------- TensorFlow & Keras -------------------- #
import tensorflow as tf                       # Core TensorFlow library
from tensorflow import keras                  # High-level API for building neural networks
from tensorflow.keras.preprocessing import image


# -------------------- Dataset Utilities -------------------- #
from tensorflow.keras.preprocessing import image_dataset_from_directory
# Load images from directories into TensorFlow datasets
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

from tensorflow.keras import layers, models
# -------------------- Layers for CNN Models ---------------- #
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D, LeakyReLU

# %% [markdown]
# # 📌 Step 2: Dataset Import or Extraction
# * This step ensures the dataset is clean, balanced, and standardized.

# %% [markdown]
# ##### 🔹 Option 1: Upload & Unzip from Local Drive

# %%
# Unzip dataset from Drive
import zipfile
zip_path = "/content/drive/MyDrive/Bengali_Taka/Bangladeshi_Paper.zip"  # Change to your file path
extract_path = "/content/drive/MyDrive/Bengali_Taka/BP"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset successfully unzipped to:", extract_path)
# Out:
# ✅ Dataset successfully unzipped to: /content/drive/MyDrive/Bengali_Taka/BP

# %% [markdown]
# ##### 🔹 Option 2: Download & Extract from Kaggle

# %%
# Install Kaggle API (if not already installed)
# !pip install -q kaggle

# Upload your Kaggle API key (kaggle.json)
from google.colab import files
files.upload()  # Choose kaggle.json from your local machine

# Move kaggle.json to the correct location
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Example: Download dataset from Kaggle
# !kaggle datasets download -d jasminpuspo/bengali-taka

# Unzip the downloaded file
import zipfile
with zipfile.ZipFile("bengali-taka.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/bengali_taka")

print("✅ Kaggle dataset downloaded and extracted successfully!")

# %% [markdown]
# ##### 🔹 Option 3: Download from Any Public URL

# %%
import requests, zipfile, io

# Example: download dataset from a direct URL
url = "https://example.com/dataset.zip"
extract_path = "/content/external_dataset"

response = requests.get(url)
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset downloaded and extracted from:", url)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nsojib/bangla-money")

print("Path to dataset files:", path)

# %% [markdown]
# ##### 🔹 Move Extracted Dataset to Drive

# %%
# !cp -r /kaggle/input/bangla-money /content/drive/MyDrive/Bengali_Taka/BM_S

# %% [markdown]
# # 📌 Step 3: Visualize Original Dataset
# * This step ensures the dataset is clean, balanced, and standardized.

# %% [markdown]
# ##### 🔹 **Root folder & Subfolder**
# * Set the dataset `root folder` and detect all class `subfolders` as class names.

# %%
root_folder = "/content/drive/MyDrive/Bengali_Taka/BP/BP_F"  # <-- change this path
class_names = [d for d in os.listdir(root_folder) if os.path.isdir(os.path.join(root_folder, d))]
print('Classes found:', class_names)
# Out:
# Classes found: ['10', '100', '1000', '2', '20', '200', '5', '50', '500']

# %% [markdown]
# ##### 🔹 **Count**
# * Count the number of images in each class.

# %%
# Count images in each class
image_counts = {cls: len(os.listdir(os.path.join(root_folder, cls))) for cls in class_names}

# Print dataset structure
for cls in class_names:
    print(f"Class '{cls}' contains {image_counts[cls]} images")
# Out:
# Class '10' contains 419 images
# Class '100' contains 565 images
# Class '1000' contains 422 images
# Class '2' contains 445 images
# Class '20' contains 480 images
# Class '200' contains 423 images
# Class '5' contains 660 images
# Class '50' contains 416 images
# Class '500' contains 1243 images

# %% [markdown]
# ##### 🔹 **Visualize Distribution**
# Plot a bar chart to show the number of images per class and check for imbalance.

# %%
# Example: image_counts is a dictionary {class_name: count}
plt.figure(figsize=(12, 6))

# Generate a list of colors automatically
colors = plt.cm.tab20(range(len(image_counts)))  # tab20 gives 20 distinct colors

bars = plt.bar(image_counts.keys(), image_counts.values(), color=colors)

# Titles and labels with bold fonts
plt.title('Original Dataset Distribution', fontsize=16, fontweight='bold')
plt.ylabel('Number of Images', fontsize=14, fontweight='bold')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12)

# Add value labels on each bar
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{int(height)}',
        ha='center', va='bottom',
        fontsize=12, fontweight='bold', color='black'
    )

plt.show()

# %%
import os
import random
import shutil

# 🔧 CHANGE THIS TO YOUR DATASET PATH
dataset_path = "/content/drive/MyDrive/Bengali_Taka/BP/BP_F"

# Number of images to keep per class
keep_count = 400

# Loop through each class folder
for class_name in os.listdir(dataset_path):
    class_folder = os.path.join(dataset_path, class_name)

    # Skip if not a folder
    if not os.path.isdir(class_folder):
        continue

    # Get all image files in the class folder
    images = [os.path.join(class_folder, f) for f in os.listdir(class_folder)
              if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    num_images = len(images)

    if num_images > keep_count:
        # Randomly select images to keep
        images_to_keep = set(random.sample(images, keep_count))
        # Delete the rest
        for img in images:
            if img not in images_to_keep:
                os.remove(img)
        print(f"✅ Class '{class_name}': reduced from {num_images} → {keep_count} images.")
    else:
        print(f"⚠️ Class '{class_name}' has only {num_images} images (less than {keep_count}), no deletion done.")

print("\n🎯 Dataset balancing complete!")
# Out:
# ✅ Class '10': reduced from 419 → 400 images.
# ✅ Class '100': reduced from 565 → 400 images.
# ✅ Class '1000': reduced from 422 → 400 images.
# ✅ Class '2': reduced from 445 → 400 images.
# ✅ Class '20': reduced from 480 → 400 images.
# ✅ Class '200': reduced from 423 → 400 images.
# ✅ Class '5': reduced from 660 → 400 images.
# ✅ Class '50': reduced from 416 → 400 images.
# ✅ Class '500': reduced from 1243 → 400 images.
#
# 🎯 Dataset balancing complete!

# %%
import os
from PIL import Image

# 🔧 Change this to your dataset path
dataset_path = "/content/drive/MyDrive/Bengali_Taka/BP/BP_F"

corrupted_images = []

# Loop through each class folder
for class_name in os.listdir(dataset_path):
    class_folder = os.path.join(dataset_path, class_name)
    if not os.path.isdir(class_folder):
        continue

    for img_name in os.listdir(class_folder):
        img_path = os.path.join(class_folder, img_name)
        if not img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue
        try:
            with Image.open(img_path) as img:
                img.verify()  # Verify if image can be opened
        except (IOError, SyntaxError) as e:
            corrupted_images.append(img_path)

# Report results
if len(corrupted_images) == 0:
    print("✅ All images are fine, no corrupted images found.")
else:
    print(f"⚠️ Found {len(corrupted_images)} corrupted images:")
    for img in corrupted_images:
        print(img)
# Out:
# ✅ All images are fine, no corrupted images found.

# %%
import os
import random
import shutil

# Paths
src_folder = "/content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/100"
dst_folder = "/content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/copy_100"

# Create destination folder if not exists
os.makedirs(dst_folder, exist_ok=True)

# Get all files (adjust extensions as needed)
all_files = [f for f in os.listdir(src_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Pick 543 random files
selected_files = random.sample(all_files, 100)

# Move files one by one
for file_name in selected_files:
    src_path = os.path.join(src_folder, file_name)
    dst_path = os.path.join(dst_folder, file_name)

    shutil.move(src_path, dst_path)  # move = copy + delete

print(f"Moved {len(selected_files)} files from {src_folder} to {dst_folder}")
# Out:
# Moved 100 files from /content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/100 to /content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/copy_100

# %%
import shutil

# Replace with your folder path in Drive
folder_path = "/content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/copy_100"

# Delete folder and all its contents
shutil.rmtree(folder_path)

print(f"✅ Deleted folder: {folder_path}")
# Out:
# ✅ Deleted folder: /content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/copy_100

# %% [markdown]
# ##### 🔹 **Rename**
# * Rename all images in each class as `classname_ID.extension`.

# %%
print("Renaming images sequentially in each class...")

for cls in os.listdir(root_folder):
    class_path = os.path.join(root_folder, cls)
    if os.path.isdir(class_path):
        images = os.listdir(class_path)
        for idx, img_name in enumerate(images, start=1):
            old_path = os.path.join(class_path, img_name)

            # New name: classname_1.jpg, classname_2.jpg, ...
            new_name = f"{cls}_{idx}.jpg"
            new_path = os.path.join(class_path, new_name)

            os.rename(old_path, new_path)

print("✅ All images renamed sequentially.")
# Out:
# Renaming images sequentially in each class...
# ✅ All images renamed sequentially.

# %% [markdown]
# Display random samples from each class with captions.

# %%
# Auto set columns (max 3 per row for readability)
n_classes = len(class_names)
cols = min(3, n_classes)              # at most 3 columns
rows = math.ceil(n_classes / cols)    # rows adjust automatically

plt.figure(figsize=(5*cols, 4*rows))  # scale figure size to layout

for i, cls in enumerate(class_names):
    images = os.listdir(os.path.join(root_folder, cls))
    sample_img = random.choice(images)
    img_path = os.path.join(root_folder, cls, sample_img)
    img = load_img(img_path, target_size=(128,128))

    plt.subplot(rows, cols, i+1)
    plt.imshow(img)
    plt.title(cls, fontsize=16, fontweight='bold')  # bold caption
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 🔹 **Resize**
# * Check all image size.
# * Resize all images to `224×224` or `299*299` pixels for consistency in training.
# * Plot the original and resize image for comparison.

# %%
dataset_path = root_folder  # change if needed

# Collect all unique image sizes
image_sizes = set()

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            img = cv2.imread(img_path)
            if img is not None:
                h, w, c = img.shape
                image_sizes.add((w, h, c))

# Show results
if len(image_sizes) == 1:
    print(f"✅ All images have the same size: {list(image_sizes)[0]} (Width x Height x Channels)")
else:
    print("⚠️ Found multiple image sizes in the dataset:")
    for size in image_sizes:
        print(f"   {size} (Width x Height x Channels)")
# Out:
# ⚠️ Found multiple image sizes in the dataset:
#    (2076, 868, 3) (Width x Height x Channels)
#    (2112, 1228, 3) (Width x Height x Channels)
#    (2340, 1128, 3) (Width x Height x Channels)
#    (1940, 1188, 3) (Width x Height x Channels)
#    (1800, 792, 3) (Width x Height x Channels)
#    (2184, 1080, 3) (Width x Height x Channels)
#    (1824, 812, 3) (Width x Height x Channels)
#    (2100, 860, 3) (Width x Height x Channels)
#    (2176, 1044, 3) (Width x Height x Channels)
#    (3044, 1259, 3) (Width x Height x Channels)
#    (3000, 1677, 3) (Width x Height x Channels)
#    (3000, 1281, 3) (Width x Height x Channels)
#    (3065, 1493, 3) (Width x Height x Channels)
#    (3026, 1276, 3) (Width x Height x Channels)
#    (2008, 900, 3) (Width x Height x Channels)
#    (2700, 1292, 3) (Width x Height x Channels)
#    (1144, 468, 3) (Width x Height x Channels)
#    (1264, 568, 3) (Width x Height x Channels)
#    (2704, 1100, 3) (Width x Height x Channels)
#    (1948, 908, 3) (Width x Height x Channels)
#    (3000, 1756, 3) (Width x Height x Channels)
#    (3010, 1450, 3) (Width x Height x Channels)
#    (3019, 1490, 3) (Width x Height x Channels)
#    (3018, 1303, 3) (Width x Height x Channels)
#    (1192, 508, 3) (Width x Height x Channels)
#    (1908, 816, 3) (Width x Height x Channels)
#    (1792, 920, 3) (Width x Height x Channels)
#    (2364, 1128, 3) (Width x Height x Channels)
#    (1352, 576, 3) (Width x Height x Channels)
#    (3000, 1311, 3) (Width x Height x Channels)
#    (3000, 1445, 3) (Width x Height x Channels)
#    (1616, 680, 3) (Width x Height x Channels)
#    (2900, 1220, 3) (Width x Height x Channels)
#    (1260, 528, 3) (Width x Height x Channels)
#    (3017, 1391, 3) (Width x Height x Channels)
#    (1840, 960, 3) (Width x Height x Channels)
#    (1912, 812, 3) (Width x Height x Channels)
#    (3042, 1274, 3) (Width x Height x Channels)
#    (3000, 1524, 3) (Width x Height x Channels)
#    (3012, 1755, 3) (Width x Height x Channels)
#    (3000, 1262, 3) (Width x Height x Channels)
#    (2372, 1060, 3) (Width x Height x Channels)
#    (2612, 1216, 3) (Width x Height x Channels)
#    (3032, 1792, 3) (Width x Height x Channels)
#    (3087, 1490, 3) (Width x Height x Channels)
#    (2216, 1084, 3) (Width x Height x Channels)
#    (3017, 1342, 3) (Width x Height x Channels)
#    (1820, 852, 3) (Width x Height x Channels)
#    (1312, 644, 3) (Width x Height x Channels)
#    (1468, 636, 3) (Width x Height x Channels)
#    (2316, 1372, 3) (Width x Height x Channels)
#    (3103, 1295, 3) (Width x Height x Channels)
#    (3000, 1737, 3) (Width x Height x Channels)
#    (3000, 1341, 3) (Width x Height x Channels)
#    (1060, 644, 3) (Width x Height x Channels)
#    (2864, 1252, 3) (Width x Height x Channels)
#    (1383, 671, 3) (Width x Height x Channels)
#    (2232, 1052, 3) (Width x Height x Channels)
#    (2340, 1055, 3) (Width x Height x Channels)
#    (1892, 892, 3) (Width x Height x Channels)
#    (3015, 1317, 3) (Width x Height x Channels)
#    (2772, 1204, 3) (Width x Height x Channels)
#    (1296, 556, 3) (Width x Height x Channels)
#    (3024, 1320, 3) (Width x Height x Channels)
#    (2280, 988, 3) (Width x Height x Channels)
#    (1916, 912, 3) (Width x Height x Channels)
#    (1592, 816, 3) (Width x Height x Channels)
#    (3008, 1378, 3) (Width x Height x Channels)
#    (2612, 1112, 3) (Width x Height x Channels)
#    (1338, 709, 3) (Width x Height x Channels)
#    (1672, 808, 3) (Width x Height x Channels)
#    (2692, 1188, 3) (Width x Height x Channels)
#    (1752, 884, 3) (Width x Height x Channels)
#    (3000, 1342, 3) (Width x Height x Channels)
#    (1312, 540, 3) (Width x Height x Channels)
#    (2600, 1140, 3) (Width x Height x Channels)
#    (1508, 808, 3) (Width x Height x Channels)
#    (3023, 1383, 3) (Width x Height x Channels)
#    (1388, 596, 3) (Width x Height x Channels)
#    (2731, 1580, 3) (Width x Height x Channels)
#    (2552, 1108, 3) (Width x Height x Channels)
#    (1932, 1164, 3) (Width x Height x Channels)
#    (1964, 824, 3) (Width x Height x Channels)
#    (3009, 1707, 3) (Width x Height x Channels)
#    (3032, 1377, 3) (Width x Height x Channels)
#    (3000, 1159, 3) (Width x Height x Channels)
#    (1612, 820, 3) (Width x Height x Channels)
#    (3000, 1293, 3) (Width x Height x Channels)
#    (2188, 1316, 3) (Width x Height x Channels)
#    (2420, 1152, 3) (Width x Height x Channels)
#    (3356, 1436, 3) (Width x Height x Channels)
#    (1136, 484, 3) (Width x Height x Channels)
#    (2928, 1232, 3) (Width x Height x Channels)
#    (2024, 920, 3) (Width x Height x Channels)
#    (1404, 580, 3) (Width x Height x Channels)
#    (2252, 1316, 3) (Width x Height x Channels)
#    (2808, 1248, 3) (Width x Height x Channels)
#    (1944, 816, 3) (Width x Height x Channels)
#    (2456, 1228, 3) (Width x Height x Channels)
#    (1860, 892, 3) (Width x Height x Channels)
#    (3000, 1372, 3) (Width x Height x Channels)
#    (1200, 572, 3) (Width x Height x Channels)
#    (3061, 1767, 3) (Width x Height x Channels)
#    (3055, 1232, 3) (Width x Height x Channels)
#    (3000, 1497, 3) (Width x Height x Channels)
#    (1408, 576, 3) (Width x Height x Channels)
#    (3000, 1323, 3) (Width x Height x Channels)
#    (2108, 1008, 3) (Width x Height x Channels)
#    (1412, 596, 3) (Width x Height x Channels)
#    (3000, 1710, 3) (Width x Height x Channels)
#    (1588, 856, 3) (Width x Height x Channels)
#    (1324, 568, 3) (Width x Height x Channels)
#    (1420, 711, 3) (Width x Height x Channels)
#    (1436, 616, 3) (Width x Height x Channels)
#    (2288, 1288, 3) (Width x Height x Channels)
#    (3009, 1208, 3) (Width x Height x Channels)
#    (2904, 1284, 3) (Width x Height x Channels)
#    (3000, 1789, 3) (Width x Height x Channels)
#    (1736, 1080, 3) (Width x Height x Channels)
#    (3051, 1242, 3) (Width x Height x Channels)
#    (3000, 1527, 3) (Width x Height x Channels)
#    (2124, 1260, 3) (Width x Height x Channels)
#    (1816, 760, 3) (Width x Height x Channels)
#    (3000, 1265, 3) (Width x Height x Channels)
#    (1292, 800, 3) (Width x Height x Channels)
#    (2864, 1176, 3) (Width x Height x Channels)
#    (1960, 864, 3) (Width x Height x Channels)
#    (1428, 714, 3) (Width x Height x Channels)
#    (3096, 1274, 3) (Width x Height x Channels)
#    (1688, 724, 3) (Width x Height x Channels)
#    (2008, 884, 3) (Width x Height x Channels)
#    (3155, 1338, 3) (Width x Height x Channels)
#    (3056, 1300, 3) (Width x Height x Channels)
#    (1416, 608, 3) (Width x Height x Channels)
#    (3000, 1353, 3) (Width x Height x Channels)
#    (1840, 780, 3) (Width x Height x Channels)
#    (1372, 568, 3) (Width x Height x Channels)
#    (3000, 1740, 3) (Width x Height x Channels)
#    (1400, 704, 3) (Width x Height x Channels)
#    (1600, 808, 3) (Width x Height x Channels)
#    (3000, 1478, 3) (Width x Height x Channels)
#    (1940, 856, 3) (Width x Height x Channels)
#    (1192, 492, 3) (Width x Height x Channels)
#    (2020, 932, 3) (Width x Height x Channels)
#    (3024, 1323, 3) (Width x Height x Channels)
#    (1828, 896, 3) (Width x Height x Channels)
#    (1812, 1116, 3) (Width x Height x Channels)
#    (1932, 820, 3) (Width x Height x Channels)
#    (3000, 1295, 3) (Width x Height x Channels)
#    (3014, 1296, 3) (Width x Height x Channels)
#    (2396, 1184, 3) (Width x Height x Channels)
#    (2752, 1208, 3) (Width x Height x Channels)
#    (3042, 1828, 3) (Width x Height x Channels)
#    (1376, 580, 3) (Width x Height x Channels)
#    (1696, 740, 3) (Width x Height x Channels)
#    (2256, 1288, 3) (Width x Height x Channels)
#    (3019, 1341, 3) (Width x Height x Channels)
#    (1372, 560, 3) (Width x Height x Channels)
#    (1208, 744, 3) (Width x Height x Channels)
#    (2776, 1228, 3) (Width x Height x Channels)
#    (2488, 1420, 3) (Width x Height x Channels)
#    (2412, 1152, 3) (Width x Height x Channels)
#    (1676, 1044, 3) (Width x Height x Channels)
#    (1836, 924, 3) (Width x Height x Channels)
#    (1240, 616, 3) (Width x Height x Channels)
#    (3000, 1508, 3) (Width x Height x Channels)
#    (2340, 1088, 3) (Width x Height x Channels)
#    (2768, 1192, 3) (Width x Height x Channels)
#    (1776, 1120, 3) (Width x Height x Channels)
#    (1200, 496, 3) (Width x Height x Channels)
#    (2480, 1172, 3) (Width x Height x Channels)
#    (1060, 628, 3) (Width x Height x Channels)
#    (3026, 1320, 3) (Width x Height x Channels)
#    (2976, 1284, 3) (Width x Height x Channels)
#    (3000, 1375, 3) (Width x Height x Channels)
#    (2860, 1216, 3) (Width x Height x Channels)
#    (1892, 876, 3) (Width x Height x Channels)
#    (3019, 1371, 3) (Width x Height x Channels)
#    (1436, 752, 3) (Width x Height x Channels)
#    (1368, 708, 3) (Width x Height x Channels)
#    (2248, 1020, 3) (Width x Height x Channels)
#    (1628, 876, 3) (Width x Height x Channels)
#    (1908, 860, 3) (Width x Height x Channels)
#    (3000, 1326, 3) (Width x Height x Channels)
#    (2760, 1304, 3) (Width x Height x Channels)
#    (2648, 1172, 3) (Width x Height x Channels)
#    (1616, 1032, 3) (Width x Height x Channels)
#    (1972, 860, 3) (Width x Height x Channels)
#    (2124, 1312, 3) (Width x Height x Channels)
#    (3027, 1303, 3) (Width x Height x Channels)
#    (2408, 1088, 3) (Width x Height x Channels)
#    (3065, 1395, 3) (Width x Height x Channels)
#    (3010, 1273, 3) (Width x Height x Channels)
#    (1300, 680, 3) (Width x Height x Channels)
#    (1656, 704, 3) (Width x Height x Channels)
#    (1674, 837, 3) (Width x Height x Channels)
#    (1316, 544, 3) (Width x Height x Channels)
#    (1768, 752, 3) (Width x Height x Channels)
#    (3000, 1405, 3) (Width x Height x Channels)
#    (2548, 1172, 3) (Width x Height x Channels)
#    (1644, 860, 3) (Width x Height x Channels)
#    (3000, 1143, 3) (Width x Height x Channels)
#    (1880, 900, 3) (Width x Height x Channels)
#    (1668, 752, 3) (Width x Height x Channels)
#    (1392, 720, 3) (Width x Height x Channels)
#    (1632, 976, 3) (Width x Height x Channels)
#    (3000, 1356, 3) (Width x Height x Channels)
#    (3019, 1218, 3) (Width x Height x Channels)
#    (1900, 800, 3) (Width x Height x Channels)
#    (1828, 820, 3) (Width x Height x Channels)
#    (1616, 800, 3) (Width x Height x Channels)
#    (3000, 1743, 3) (Width x Height x Channels)
#    (1496, 816, 3) (Width x Height x Channels)
#    (1344, 560, 3) (Width x Height x Channels)
#    (1964, 888, 3) (Width x Height x Channels)
#    (3119, 1294, 3) (Width x Height x Channels)
#    (1564, 948, 3) (Width x Height x Channels)
#    (1932, 832, 3) (Width x Height x Channels)
#    (3000, 1307, 3) (Width x Height x Channels)
#    (1336, 524, 3) (Width x Height x Channels)
#    (1832, 944, 3) (Width x Height x Channels)
#    (1668, 1044, 3) (Width x Height x Channels)
#    (3058, 1349, 3) (Width x Height x Channels)
#    (3043, 1585, 3) (Width x Height x Channels)
#    (1404, 728, 3) (Width x Height x Channels)
#    (1864, 888, 3) (Width x Height x Channels)
#    (1324, 552, 3) (Width x Height x Channels)
#    (1752, 756, 3) (Width x Height x Channels)
#    (1436, 600, 3) (Width x Height x Channels)
#    (3000, 1386, 3) (Width x Height x Channels)
#    (3028, 1846, 3) (Width x Height x Channels)
#    (3056, 1333, 3) (Width x Height x Channels)
#    (3009, 1192, 3) (Width x Height x Channels)
#    (1892, 1140, 3) (Width x Height x Channels)
#    (1936, 828, 3) (Width x Height x Channels)
#    (1316, 516, 3) (Width x Height x Channels)
#    (1460, 620, 3) (Width x Height x Channels)
#    (3000, 1511, 3) (Width x Height x Channels)
#    (1104, 468, 3) (Width x Height x Channels)
#    (1816, 1140, 3) (Width x Height x Channels)
#    (1648, 1036, 3) (Width x Height x Channels)
#    (1960, 848, 3) (Width x Height x Channels)
#    (2732, 1316, 3) (Width x Height x Channels)
#    (2080, 848, 3) (Width x Height x Channels)
#    (1020, 644, 3) (Width x Height x Channels)
#    (1380, 604, 3) (Width x Height x Channels)
#    (2580, 1076, 3) (Width x Height x Channels)
#    (1168, 584, 3) (Width x Height x Channels)
#    (3000, 1724, 3) (Width x Height x Channels)
#    (3080, 1304, 3) (Width x Height x Channels)
#    (3013, 1338, 3) (Width x Height x Channels)
#    (1356, 688, 3) (Width x Height x Channels)
#    (1940, 840, 3) (Width x Height x Channels)
#    (1900, 860, 3) (Width x Height x Channels)
#    (2876, 1296, 3) (Width x Height x Channels)
#    (2100, 908, 3) (Width x Height x Channels)
#    (2552, 1144, 3) (Width x Height x Channels)
#    (3000, 1541, 3) (Width x Height x Channels)
#    (1968, 1064, 3) (Width x Height x Channels)
#    (3023, 1507, 3) (Width x Height x Channels)
#    (2000, 936, 3) (Width x Height x Channels)
#    (3000, 1329, 3) (Width x Height x Channels)
#    (1220, 516, 3) (Width x Height x Channels)
#    (2116, 876, 3) (Width x Height x Channels)
#    (1872, 900, 3) (Width x Height x Channels)
#    (3000, 1754, 3) (Width x Height x Channels)
#    (3035, 1421, 3) (Width x Height x Channels)
#    (1832, 792, 3) (Width x Height x Channels)
#    (3026, 1487, 3) (Width x Height x Channels)
#    (2644, 1184, 3) (Width x Height x Channels)
#    (1584, 980, 3) (Width x Height x Channels)
#    (1820, 948, 3) (Width x Height x Channels)
#    (3150, 1370, 3) (Width x Height x Channels)
#    (1976, 868, 3) (Width x Height x Channels)
#    (1459, 689, 3) (Width x Height x Channels)
#    (3038, 1401, 3) (Width x Height x Channels)
#    (2120, 1284, 3) (Width x Height x Channels)
#    (1968, 832, 3) (Width x Height x Channels)
#    (1184, 520, 3) (Width x Height x Channels)
#    (3000, 1359, 3) (Width x Height x Channels)
#    (2104, 1196, 3) (Width x Height x Channels)
#    (1132, 568, 3) (Width x Height x Channels)
#    (3000, 1438, 3) (Width x Height x Channels)
#    (1364, 672, 3) (Width x Height x Channels)
#    (3044, 1288, 3) (Width x Height x Channels)
#    (3000, 1572, 3) (Width x Height x Channels)
#    (3000, 1310, 3) (Width x Height x Channels)
#    (2784, 1308, 3) (Width x Height x Channels)
#    (1180, 480, 3) (Width x Height x Channels)
#    (1856, 864, 3) (Width x Height x Channels)
#    (1316, 528, 3) (Width x Height x Channels)
#    (932, 568, 3) (Width x Height x Channels)
#    (3000, 1389, 3) (Width x Height x Channels)
#    (1292, 528, 3) (Width x Height x Channels)
#    (1568, 972, 3) (Width x Height x Channels)
#    (2000, 868, 3) (Width x Height x Channels)
#    (2064, 996, 3) (Width x Height x Channels)
#    (1340, 548, 3) (Width x Height x Channels)
#    (3000, 1776, 3) (Width x Height x Channels)
#    (2112, 1016, 3) (Width x Height x Channels)
#    (2220, 1256, 3) (Width x Height x Channels)
#    (3005, 1313, 3) (Width x Height x Channels)
#    (3048, 1300, 3) (Width x Height x Channels)
#    (1988, 1024, 3) (Width x Height x Channels)
#    (2656, 1088, 3) (Width x Height x Channels)
#    (1824, 1124, 3) (Width x Height x Channels)
#    (3015, 1790, 3) (Width x Height x Channels)
#    (3024, 1225, 3) (Width x Height x Channels)
#    (2244, 1276, 3) (Width x Height x Channels)
#    (3000, 1206, 3) (Width x Height x Channels)
#    (3000, 1340, 3) (Width x Height x Channels)
#    (1748, 728, 3) (Width x Height x Channels)
#    (1440, 624, 3) (Width x Height x Channels)
#    (2788, 1320, 3) (Width x Height x Channels)
#    (2368, 1084, 3) (Width x Height x Channels)
#    (3020, 1290, 3) (Width x Height x Channels)
#    (1496, 800, 3) (Width x Height x Channels)
#    (1816, 960, 3) (Width x Height x Channels)
#    (1960, 1064, 3) (Width x Height x Channels)
#    (3008, 1842, 3) (Width x Height x Channels)
#    (1964, 872, 3) (Width x Height x Channels)
#    (2860, 1260, 3) (Width x Height x Channels)
#    (1216, 508, 3) (Width x Height x Channels)
#    (1644, 1008, 3) (Width x Height x Channels)
#    (2536, 1180, 3) (Width x Height x Channels)
#    (3008, 1272, 3) (Width x Height x Channels)
#    (3000, 1544, 3) (Width x Height x Channels)
#    (2068, 968, 3) (Width x Height x Channels)
#    (1908, 1212, 3) (Width x Height x Channels)
#    (3023, 1510, 3) (Width x Height x Channels)
#    (2372, 1476, 3) (Width x Height x Channels)
#    (3040, 1278, 3) (Width x Height x Channels)
#    (2640, 1276, 3) (Width x Height x Channels)
#    (1576, 980, 3) (Width x Height x Channels)
#    (2244, 1044, 3) (Width x Height x Channels)
#    (3000, 1370, 3) (Width x Height x Channels)
#    (1944, 864, 3) (Width x Height x Channels)
#    (1128, 480, 3) (Width x Height x Channels)
#    (2564, 1204, 3) (Width x Height x Channels)
#    (1308, 548, 3) (Width x Height x Channels)
#    (3000, 1757, 3) (Width x Height x Channels)
#    (1896, 832, 3) (Width x Height x Channels)
#    (1816, 856, 3) (Width x Height x Channels)
#    (1968, 884, 3) (Width x Height x Channels)
#    (2988, 1264, 3) (Width x Height x Channels)
#    (2232, 1072, 3) (Width x Height x Channels)
#    (2396, 1384, 3) (Width x Height x Channels)
#    (1648, 1020, 3) (Width x Height x Channels)
#    (3030, 1797, 3) (Width x Height x Channels)
#    (1264, 648, 3) (Width x Height x Channels)
#    (2580, 1188, 3) (Width x Height x Channels)
#    (2336, 1084, 3) (Width x Height x Channels)
#    (3000, 1574, 3) (Width x Height x Channels)
#    (1288, 540, 3) (Width x Height x Channels)
#    (1404, 608, 3) (Width x Height x Channels)
#    (3013, 1846, 3) (Width x Height x Channels)
#    (1512, 748, 3) (Width x Height x Channels)
#    (1328, 636, 3) (Width x Height x Channels)
#    (3017, 1392, 3) (Width x Height x Channels)
#    (1820, 768, 3) (Width x Height x Channels)
#    (1900, 844, 3) (Width x Height x Channels)
#    (3033, 1297, 3) (Width x Height x Channels)
#    (1156, 512, 3) (Width x Height x Channels)
#    (1704, 872, 3) (Width x Height x Channels)
#    (1776, 924, 3) (Width x Height x Channels)
#    (2160, 1212, 3) (Width x Height x Channels)
#    (1964, 844, 3) (Width x Height x Channels)
#    (1304, 524, 3) (Width x Height x Channels)
#    (1544, 780, 3) (Width x Height x Channels)
#    (1848, 864, 3) (Width x Height x Channels)
#    (2000, 920, 3) (Width x Height x Channels)
#    (1220, 500, 3) (Width x Height x Channels)
#    (2192, 1044, 3) (Width x Height x Channels)
#    (2024, 940, 3) (Width x Height x Channels)
#    (3156, 1368, 3) (Width x Height x Channels)
#    (3000, 1258, 3) (Width x Height x Channels)
#    (1356, 568, 3) (Width x Height x Channels)
#    (3000, 1392, 3) (Width x Height x Channels)
#    (1896, 1200, 3) (Width x Height x Channels)
#    (1436, 644, 3) (Width x Height x Channels)
#    (1584, 964, 3) (Width x Height x Channels)
#    (1384, 704, 3) (Width x Height x Channels)
#    (1668, 876, 3) (Width x Height x Channels)
#    (1636, 820, 3) (Width x Height x Channels)
#    (3014, 1393, 3) (Width x Height x Channels)
#    (3536, 1512, 3) (Width x Height x Channels)
#    (1548, 792, 3) (Width x Height x Channels)
#    (2872, 1256, 3) (Width x Height x Channels)
#    (1852, 876, 3) (Width x Height x Channels)
#    (1456, 744, 3) (Width x Height x Channels)
#    (1492, 608, 3) (Width x Height x Channels)
#    (3000, 1209, 3) (Width x Height x Channels)
#    (2080, 892, 3) (Width x Height x Channels)
#    (3000, 1343, 3) (Width x Height x Channels)
#    (1612, 1004, 3) (Width x Height x Channels)
#    (3000, 1422, 3) (Width x Height x Channels)
#    (1196, 552, 3) (Width x Height x Channels)
#    (3000, 1160, 3) (Width x Height x Channels)
#    (1908, 828, 3) (Width x Height x Channels)
#    (1536, 924, 3) (Width x Height x Channels)
#    (1960, 884, 3) (Width x Height x Channels)
#    (3162, 1307, 3) (Width x Height x Channels)
#    (3092, 1312, 3) (Width x Height x Channels)
#    (3000, 1373, 3) (Width x Height x Channels)
#    (3004, 1418, 3) (Width x Height x Channels)
#    (3033, 1308, 3) (Width x Height x Channels)
#    (3000, 1760, 3) (Width x Height x Channels)
#    (3010, 1454, 3) (Width x Height x Channels)
#    (3046, 1318, 3) (Width x Height x Channels)
#    (1804, 896, 3) (Width x Height x Channels)
#    (1396, 608, 3) (Width x Height x Channels)
#    (1780, 896, 3) (Width x Height x Channels)
#    (2012, 1028, 3) (Width x Height x Channels)
#    (3000, 1324, 3) (Width x Height x Channels)
#    (2400, 1124, 3) (Width x Height x Channels)
#    (1548, 948, 3) (Width x Height x Channels)
#    (3000, 1973, 3) (Width x Height x Channels)
#    (3010, 1271, 3) (Width x Height x Channels)
#    (1696, 888, 3) (Width x Height x Channels)
#    (1812, 828, 3) (Width x Height x Channels)
#    (1760, 888, 3) (Width x Height x Channels)
#    (3000, 1403, 3) (Width x Height x Channels)
#    (3035, 1466, 3) (Width x Height x Channels)
#    (1728, 832, 3) (Width x Height x Channels)
#    (1640, 704, 3) (Width x Height x Channels)
#    (3015, 1245, 3) (Width x Height x Channels)
#    (1676, 1064, 3) (Width x Height x Channels)
#    (3000, 1790, 3) (Width x Height x Channels)
#    (3010, 1484, 3) (Width x Height x Channels)
#    (1368, 564, 3) (Width x Height x Channels)
#    (1600, 992, 3) (Width x Height x Channels)
#    (1864, 984, 3) (Width x Height x Channels)
#    (2572, 1240, 3) (Width x Height x Channels)
#    (1936, 924, 3) (Width x Height x Channels)
#    (3000, 1741, 3) (Width x Height x Channels)
#    (1844, 876, 3) (Width x Height x Channels)
#    (2556, 1152, 3) (Width x Height x Channels)
#    (3284, 1408, 3) (Width x Height x Channels)
#    (3024, 1324, 3) (Width x Height x Channels)
#    (2580, 1172, 3) (Width x Height x Channels)
#    (3042, 1704, 3) (Width x Height x Channels)
#    (3000, 1820, 3) (Width x Height x Channels)
#    (1784, 1072, 3) (Width x Height x Channels)
#    (3080, 1534, 3) (Width x Height x Channels)
#    (2936, 1212, 3) (Width x Height x Channels)
#    (1628, 1024, 3) (Width x Height x Channels)
#    (1404, 592, 3) (Width x Height x Channels)
#    (1280, 600, 3) (Width x Height x Channels)
#    (3008, 1673, 3) (Width x Height x Channels)
#    (3020, 1171, 3) (Width x Height x Channels)
#    (1480, 776, 3) (Width x Height x Channels)
#    (1400, 572, 3) (Width x Height x Channels)
#    (3000, 1212, 3) (Width x Height x Channels)
#    (1780, 828, 3) (Width x Height x Channels)
#    (1360, 592, 3) (Width x Height x Channels)
#    (1900, 828, 3) (Width x Height x Channels)
#    (3000, 1637, 3) (Width x Height x Channels)
#    (3000, 1771, 3) (Width x Height x Channels)
#    (1964, 828, 3) (Width x Height x Channels)
#    (1464, 688, 3) (Width x Height x Channels)
#    (3000, 1425, 3) (Width x Height x Channels)
#    (1680, 744, 3) (Width x Height x Channels)
#    (2392, 1020, 3) (Width x Height x Channels)
#    (1532, 920, 3) (Width x Height x Channels)
#    (1524, 696, 3) (Width x Height x Channels)
#    (1760, 820, 3) (Width x Height x Channels)
#    (3008, 1278, 3) (Width x Height x Channels)
#    (1872, 868, 3) (Width x Height x Channels)
#    (3027, 1274, 3) (Width x Height x Channels)
#    (1332, 532, 3) (Width x Height x Channels)
#    (1404, 584, 3) (Width x Height x Channels)
#    (1204, 496, 3) (Width x Height x Channels)
#    (3000, 1242, 3) (Width x Height x Channels)
#    (1356, 552, 3) (Width x Height x Channels)
#    (3000, 1376, 3) (Width x Height x Channels)
#    (1556, 728, 3) (Width x Height x Channels)
#    (2016, 888, 3) (Width x Height x Channels)
#    (2360, 1068, 3) (Width x Height x Channels)
#    (1692, 880, 3) (Width x Height x Channels)
#    (1968, 928, 3) (Width x Height x Channels)
#    (1852, 860, 3) (Width x Height x Channels)
#    (1428, 592, 3) (Width x Height x Channels)
#    (1488, 784, 3) (Width x Height x Channels)
#    (3000, 1455, 3) (Width x Height x Channels)
#    (1456, 728, 3) (Width x Height x Channels)
#    (1912, 1168, 3) (Width x Height x Channels)
#    (1336, 544, 3) (Width x Height x Channels)
#    (1096, 460, 3) (Width x Height x Channels)
#    (1416, 620, 3) (Width x Height x Channels)
#    (3068, 1325, 3) (Width x Height x Channels)
#    (2392, 1100, 3) (Width x Height x Channels)
#    (1208, 508, 3) (Width x Height x Channels)
#    (3035, 1419, 3) (Width x Height x Channels)
#    (3000, 1668, 3) (Width x Height x Channels)
#    (3000, 1406, 3) (Width x Height x Channels)
#    (1368, 576, 3) (Width x Height x Channels)
#    (3029, 1271, 3) (Width x Height x Channels)
#    (3014, 1145, 3) (Width x Height x Channels)
#    (3106, 1714, 3) (Width x Height x Channels)
#    (3384, 1432, 3) (Width x Height x Channels)
#    (2792, 1328, 3) (Width x Height x Channels)
#    (1772, 948, 3) (Width x Height x Channels)
#    (1384, 544, 3) (Width x Height x Channels)
#    (3000, 1223, 3) (Width x Height x Channels)
#    (3009, 1425, 3) (Width x Height x Channels)
#    (3000, 1357, 3) (Width x Height x Channels)
#    (1764, 912, 3) (Width x Height x Channels)
#    (1952, 832, 3) (Width x Height x Channels)
#    (1756, 860, 3) (Width x Height x Channels)
#    (1880, 852, 3) (Width x Height x Channels)
#    (1396, 592, 3) (Width x Height x Channels)
#    (3000, 1436, 3) (Width x Height x Channels)
#    (1748, 824, 3) (Width x Height x Channels)
#    (3000, 1174, 3) (Width x Height x Channels)
#    (1464, 612, 3) (Width x Height x Channels)
#    (3018, 1370, 3) (Width x Height x Channels)
#    (1884, 792, 3) (Width x Height x Channels)
#    (3000, 1387, 3) (Width x Height x Channels)
#    (1220, 536, 3) (Width x Height x Channels)
#    (3011, 1421, 3) (Width x Height x Channels)
#    (1924, 860, 3) (Width x Height x Channels)
#    (1524, 920, 3) (Width x Height x Channels)
#    (1720, 764, 3) (Width x Height x Channels)
#    (1400, 604, 3) (Width x Height x Channels)
#    (1676, 1048, 3) (Width x Height x Channels)
#    (1560, 672, 3) (Width x Height x Channels)
#    (1944, 960, 3) (Width x Height x Channels)
#    (1712, 728, 3) (Width x Height x Channels)
#    (3092, 1277, 3) (Width x Height x Channels)
#    (2176, 1092, 3) (Width x Height x Channels)
#    (2640, 1160, 3) (Width x Height x Channels)
#    (2960, 1320, 3) (Width x Height x Channels)
#    (1824, 776, 3) (Width x Height x Channels)
#    (3015, 1442, 3) (Width x Height x Channels)
#    (3000, 1853, 3) (Width x Height x Channels)
#    (3000, 1591, 3) (Width x Height x Channels)
#    (3019, 1250, 3) (Width x Height x Channels)
#    (1420, 592, 3) (Width x Height x Channels)
#    (1696, 1036, 3) (Width x Height x Channels)
#    (1492, 644, 3) (Width x Height x Channels)
#    (1652, 824, 3) (Width x Height x Channels)
#    (3039, 1596, 3) (Width x Height x Channels)
#    (2976, 1288, 3) (Width x Height x Channels)
#    (1216, 596, 3) (Width x Height x Channels)
#    (2196, 1264, 3) (Width x Height x Channels)
#    (3009, 1357, 3) (Width x Height x Channels)
#    (2492, 1524, 3) (Width x Height x Channels)
#    (3276, 1356, 3) (Width x Height x Channels)
#    (3000, 1804, 3) (Width x Height x Channels)
#    (3015, 1393, 3) (Width x Height x Channels)
#    (1416, 760, 3) (Width x Height x Channels)
#    (2336, 1052, 3) (Width x Height x Channels)
#    (2340, 1122, 3) (Width x Height x Channels)
#    (3011, 1277, 3) (Width x Height x Channels)
#    (1520, 768, 3) (Width x Height x Channels)
#    (1676, 732, 3) (Width x Height x Channels)
#    (3014, 1459, 3) (Width x Height x Channels)
#    (1940, 920, 3) (Width x Height x Channels)
#    (3000, 1196, 3) (Width x Height x Channels)
#    (1908, 864, 3) (Width x Height x Channels)
#    (2104, 908, 3) (Width x Height x Channels)
#    (1360, 576, 3) (Width x Height x Channels)
#    (1512, 632, 3) (Width x Height x Channels)
#    (1900, 812, 3) (Width x Height x Channels)
#    (1352, 540, 3) (Width x Height x Channels)
#    (3144, 1288, 3) (Width x Height x Channels)
#    (3020, 1234, 3) (Width x Height x Channels)
#    (2340, 1073, 3) (Width x Height x Channels)
#    (3000, 1275, 3) (Width x Height x Channels)
#    (3000, 1805, 3) (Width x Height x Channels)
#    (3000, 1409, 3) (Width x Height x Channels)
#    (1880, 904, 3) (Width x Height x Channels)
#    (3015, 1289, 3) (Width x Height x Channels)
#    (1484, 772, 3) (Width x Height x Channels)
#    (2968, 1416, 3) (Width x Height x Channels)
#    (2532, 1188, 3) (Width x Height x Channels)
#    (3000, 1488, 3) (Width x Height x Channels)
#    (3000, 1226, 3) (Width x Height x Channels)
#    (2372, 1024, 3) (Width x Height x Channels)
#    (2608, 1148, 3) (Width x Height x Channels)
#    (2524, 1152, 3) (Width x Height x Channels)
#    (3047, 1296, 3) (Width x Height x Channels)
#    (3010, 1307, 3) (Width x Height x Channels)
#    (1904, 912, 3) (Width x Height x Channels)
#    (1424, 768, 3) (Width x Height x Channels)
#    (2792, 1148, 3) (Width x Height x Channels)
#    (1900, 892, 3) (Width x Height x Channels)
#    (3031, 1279, 3) (Width x Height x Channels)
#    (3000, 1701, 3) (Width x Height x Channels)
#    (1504, 760, 3) (Width x Height x Channels)
#    (2976, 1348, 3) (Width x Height x Channels)
#    (988, 628, 3) (Width x Height x Channels)
#    (3000, 1439, 3) (Width x Height x Channels)
#    (1486, 880, 3) (Width x Height x Channels)
#    (2944, 1292, 3) (Width x Height x Channels)
#    (1416, 732, 3) (Width x Height x Channels)
#    (2200, 960, 3) (Width x Height x Channels)
#    (1452, 596, 3) (Width x Height x Channels)
#    (3008, 1292, 3) (Width x Height x Channels)
#    (2024, 1200, 3) (Width x Height x Channels)
#    (3088, 1284, 3) (Width x Height x Channels)
#    (3000, 1256, 3) (Width x Height x Channels)
#    (3080, 1232, 3) (Width x Height x Channels)
#    (3320, 1416, 3) (Width x Height x Channels)
#    (3000, 1390, 3) (Width x Height x Channels)
#    (1400, 616, 3) (Width x Height x Channels)
#    (1368, 560, 3) (Width x Height x Channels)
#    (1520, 616, 3) (Width x Height x Channels)
#    (1864, 980, 3) (Width x Height x Channels)
#    (1904, 904, 3) (Width x Height x Channels)
#    (3019, 1252, 3) (Width x Height x Channels)
#    (1080, 668, 3) (Width x Height x Channels)
#    (1432, 588, 3) (Width x Height x Channels)
#    (1896, 852, 3) (Width x Height x Channels)
#    (1276, 512, 3) (Width x Height x Channels)
#    (1148, 504, 3) (Width x Height x Channels)
#    (3000, 1469, 3) (Width x Height x Channels)
#    (3029, 1730, 3) (Width x Height x Channels)
#    (3000, 1207, 3) (Width x Height x Channels)
#    (1680, 788, 3) (Width x Height x Channels)
#    (2544, 1092, 3) (Width x Height x Channels)
#    (3025, 1314, 3) (Width x Height x Channels)
#    (3048, 1380, 3) (Width x Height x Channels)
#    (1472, 760, 3) (Width x Height x Channels)
#    (2184, 1036, 3) (Width x Height x Channels)
#    (3000, 1420, 3) (Width x Height x Channels)
#    (3012, 1255, 3) (Width x Height x Channels)
#    (3009, 1226, 3) (Width x Height x Channels)
#    (1984, 876, 3) (Width x Height x Channels)
#    (1520, 780, 3) (Width x Height x Channels)
#    (3032, 1292, 3) (Width x Height x Channels)
#    (3300, 1388, 3) (Width x Height x Channels)
#    (3103, 1319, 3) (Width x Height x Channels)
#    (1192, 484, 3) (Width x Height x Channels)
#    (1344, 540, 3) (Width x Height x Channels)
#    (1180, 724, 3) (Width x Height x Channels)
#    (3000, 1237, 3) (Width x Height x Channels)
#    (1532, 956, 3) (Width x Height x Channels)
#    (3029, 1414, 3) (Width x Height x Channels)
#    (1400, 588, 3) (Width x Height x Channels)
#    (1528, 712, 3) (Width x Height x Channels)
#    (3084, 1274, 3) (Width x Height x Channels)
#    (1948, 864, 3) (Width x Height x Channels)
#    (3124, 1332, 3) (Width x Height x Channels)
#    (1324, 532, 3) (Width x Height x Channels)
#    (3000, 1450, 3) (Width x Height x Channels)
#    (1708, 992, 3) (Width x Height x Channels)
#    (3015, 1292, 3) (Width x Height x Channels)
#    (1984, 1040, 3) (Width x Height x Channels)
#    (1584, 676, 3) (Width x Height x Channels)
#    (1844, 972, 3) (Width x Height x Channels)
#    (3000, 1229, 3) (Width x Height x Channels)
#    (3296, 1236, 3) (Width x Height x Channels)
#    (3092, 1340, 3) (Width x Height x Channels)
#    (3000, 1663, 3) (Width x Height x Channels)
#    (1256, 676, 3) (Width x Height x Channels)
#    (1292, 540, 3) (Width x Height x Channels)
#    (1916, 1012, 3) (Width x Height x Channels)
#    (2580, 1140, 3) (Width x Height x Channels)
#    (3015, 1243, 3) (Width x Height x Channels)
#    (3016, 1459, 3) (Width x Height x Channels)
#    (3000, 1442, 3) (Width x Height x Channels)
#    (2956, 1788, 3) (Width x Height x Channels)
#    (2264, 1000, 3) (Width x Height x Channels)
#    (1248, 512, 3) (Width x Height x Channels)
#    (1908, 848, 3) (Width x Height x Channels)
#    (3072, 1332, 3) (Width x Height x Channels)
#    (1360, 560, 3) (Width x Height x Channels)
#    (1868, 840, 3) (Width x Height x Channels)
#    (3015, 1322, 3) (Width x Height x Channels)
#    (3000, 1867, 3) (Width x Height x Channels)
#    (2128, 912, 3) (Width x Height x Channels)
#    (1464, 656, 3) (Width x Height x Channels)
#    (3039, 1872, 3) (Width x Height x Channels)
#    (1296, 552, 3) (Width x Height x Channels)
#    (1572, 996, 3) (Width x Height x Channels)
#    (3000, 1259, 3) (Width x Height x Channels)
#    (1688, 764, 3) (Width x Height x Channels)
#    (2512, 1088, 3) (Width x Height x Channels)
#    (1764, 1120, 3) (Width x Height x Channels)
#    (2148, 1012, 3) (Width x Height x Channels)
#    (1688, 852, 3) (Width x Height x Channels)
#    (1364, 572, 3) (Width x Height x Channels)
#    (3000, 1868, 3) (Width x Height x Channels)
#    (3000, 1210, 3) (Width x Height x Channels)
#    (1496, 679, 3) (Width x Height x Channels)
#    (1792, 764, 3) (Width x Height x Channels)
#    (3005, 1530, 3) (Width x Height x Channels)
#    (3016, 1440, 3) (Width x Height x Channels)
#    (3010, 1379, 3) (Width x Height x Channels)
#    (1812, 848, 3) (Width x Height x Channels)
#    (3083, 1294, 3) (Width x Height x Channels)
#    (3000, 1423, 3) (Width x Height x Channels)
#    (1924, 896, 3) (Width x Height x Channels)
#    (1880, 784, 3) (Width x Height x Channels)
#    (1144, 476, 3) (Width x Height x Channels)
#    (1376, 708, 3) (Width x Height x Channels)
#    (2264, 1368, 3) (Width x Height x Channels)
#    (2700, 1172, 3) (Width x Height x Channels)
#    (3160, 1332, 3) (Width x Height x Channels)
#    (3063, 1398, 3) (Width x Height x Channels)
#    (1288, 680, 3) (Width x Height x Channels)
#    (3011, 1283, 3) (Width x Height x Channels)
#    (2336, 1096, 3) (Width x Height x Channels)
#    (2224, 964, 3) (Width x Height x Channels)
#    (3028, 1313, 3) (Width x Height x Channels)
#    (1868, 812, 3) (Width x Height x Channels)
#    (1956, 840, 3) (Width x Height x Channels)
#    (3000, 1636, 3) (Width x Height x Channels)
#    (3000, 1240, 3) (Width x Height x Channels)
#    (1540, 812, 3) (Width x Height x Channels)
#    (3031, 1817, 3) (Width x Height x Channels)
#    (3148, 1448, 3) (Width x Height x Channels)
#    (1515, 755, 3) (Width x Height x Channels)
#    (1544, 620, 3) (Width x Height x Channels)
#    (1964, 1168, 3) (Width x Height x Channels)
#    (1148, 488, 3) (Width x Height x Channels)
#    (3000, 1453, 3) (Width x Height x Channels)
#    (1700, 880, 3) (Width x Height x Channels)
#    (3000, 1191, 3) (Width x Height x Channels)
#    (2656, 1152, 3) (Width x Height x Channels)
#    (3045, 1273, 3) (Width x Height x Channels)
#    (2888, 1256, 3) (Width x Height x Channels)
#    (1480, 796, 3) (Width x Height x Channels)
#    (2376, 1184, 3) (Width x Height x Channels)
#    (1552, 948, 3) (Width x Height x Channels)
#    (3000, 1270, 3) (Width x Height x Channels)
#    (3000, 1404, 3) (Width x Height x Channels)
#    (1856, 1132, 3) (Width x Height x Channels)
#    (3013, 1280, 3) (Width x Height x Channels)
#    (3030, 1310, 3) (Width x Height x Channels)
#    (2216, 1092, 3) (Width x Height x Channels)
#    (1828, 784, 3) (Width x Height x Channels)
#    (2340, 1109, 3) (Width x Height x Channels)
#    (1696, 840, 3) (Width x Height x Channels)
#    (3000, 1483, 3) (Width x Height x Channels)
#    (1424, 600, 3) (Width x Height x Channels)
#    (3014, 1184, 3) (Width x Height x Channels)
#    (1568, 804, 3) (Width x Height x Channels)
#    (3000, 1870, 3) (Width x Height x Channels)
#    (2036, 976, 3) (Width x Height x Channels)
#    (1948, 848, 3) (Width x Height x Channels)
#    (1748, 1084, 3) (Width x Height x Channels)
#    (1252, 536, 3) (Width x Height x Channels)
#    (3035, 1497, 3) (Width x Height x Channels)
#    (3015, 1934, 3) (Width x Height x Channels)
#    (3025, 1407, 3) (Width x Height x Channels)
#    (3031, 1443, 3) (Width x Height x Channels)
#    (1196, 480, 3) (Width x Height x Channels)
#    (3000, 1821, 3) (Width x Height x Channels)
#    (1896, 896, 3) (Width x Height x Channels)
#    (3000, 1088, 3) (Width x Height x Channels)
#    (1428, 612, 3) (Width x Height x Channels)
#    (3040, 1421, 3) (Width x Height x Channels)
#    (3011, 1294, 3) (Width x Height x Channels)
#    (1680, 1056, 3) (Width x Height x Channels)
#    (2938, 1426, 3) (Width x Height x Channels)
#    (1463, 747, 3) (Width x Height x Channels)
#    (3005, 1408, 3) (Width x Height x Channels)
#    (1776, 784, 3) (Width x Height x Channels)
#    (3041, 1272, 3) (Width x Height x Channels)
#    (1888, 860, 3) (Width x Height x Channels)
#    (1488, 892, 3) (Width x Height x Channels)
#    (1840, 1124, 3) (Width x Height x Channels)
#    (1380, 568, 3) (Width x Height x Channels)
#    (1920, 804, 3) (Width x Height x Channels)
#    (2816, 1164, 3) (Width x Height x Channels)
#    (1396, 844, 3) (Width x Height x Channels)
#    (3006, 1178, 3) (Width x Height x Channels)
#    (1248, 624, 3) (Width x Height x Channels)
#    (1744, 1044, 3) (Width x Height x Channels)
#    (3000, 1426, 3) (Width x Height x Channels)
#    (1360, 544, 3) (Width x Height x Channels)
#    (1868, 824, 3) (Width x Height x Channels)
#    (2020, 880, 3) (Width x Height x Channels)
#    (1348, 700, 3) (Width x Height x Channels)
#    (1384, 564, 3) (Width x Height x Channels)
#    (1296, 536, 3) (Width x Height x Channels)
#    (3000, 1639, 3) (Width x Height x Channels)
#    (3000, 1243, 3) (Width x Height x Channels)
#    (3007, 1404, 3) (Width x Height x Channels)
#    (1408, 584, 3) (Width x Height x Channels)
#    (1684, 1028, 3) (Width x Height x Channels)
#    (1452, 796, 3) (Width x Height x Channels)
#    (2664, 1128, 3) (Width x Height x Channels)
#    (1068, 424, 3) (Width x Height x Channels)
#    (3000, 1718, 3) (Width x Height x Channels)
#    (1364, 556, 3) (Width x Height x Channels)
#    (3000, 1456, 3) (Width x Height x Channels)
#    (1388, 576, 3) (Width x Height x Channels)
#    (1664, 1020, 3) (Width x Height x Channels)
#    (1516, 700, 3) (Width x Height x Channels)
#    (3036, 1532, 3) (Width x Height x Channels)
#    (1392, 780, 3) (Width x Height x Channels)
#    (3021, 1185, 3) (Width x Height x Channels)
#    (2340, 1071, 3) (Width x Height x Channels)
#    (3000, 1273, 3) (Width x Height x Channels)
#    (3000, 1407, 3) (Width x Height x Channels)
#    (1888, 1016, 3) (Width x Height x Channels)
#    (1304, 540, 3) (Width x Height x Channels)
#    (1892, 824, 3) (Width x Height x Channels)
#    (1376, 692, 3) (Width x Height x Channels)
#    (2384, 1128, 3) (Width x Height x Channels)
#    (3031, 1192, 3) (Width x Height x Channels)
#    (3006, 1372, 3) (Width x Height x Channels)
#    (3120, 1336, 3) (Width x Height x Channels)
#    (3052, 1388, 3) (Width x Height x Channels)
#    (3000, 1486, 3) (Width x Height x Channels)
#    (3041, 1245, 3) (Width x Height x Channels)
#    (3000, 1224, 3) (Width x Height x Channels)
#    (1940, 864, 3) (Width x Height x Channels)
#    (2020, 940, 3) (Width x Height x Channels)
#    (1540, 796, 3) (Width x Height x Channels)
#    (3011, 1346, 3) (Width x Height x Channels)
#    (1652, 844, 3) (Width x Height x Channels)
#    (1700, 992, 3) (Width x Height x Channels)
#    (3005, 1460, 3) (Width x Height x Channels)
#    (3000, 1699, 3) (Width x Height x Channels)
#    (3000, 1303, 3) (Width x Height x Channels)
#    (3000, 1437, 3) (Width x Height x Channels)
#    (1108, 464, 3) (Width x Height x Channels)
#    (1288, 656, 3) (Width x Height x Channels)
#    (1404, 724, 3) (Width x Height x Channels)
#    (2260, 976, 3) (Width x Height x Channels)
#    (1444, 608, 3) (Width x Height x Channels)
#    (3000, 1304, 3) (Width x Height x Channels)
#    (3004, 1215, 3) (Width x Height x Channels)
#    (1432, 636, 3) (Width x Height x Channels)
#    (3224, 1384, 3) (Width x Height x Channels)
#    (3014, 1430, 3) (Width x Height x Channels)
#    (956, 428, 3) (Width x Height x Channels)
#    (3031, 1223, 3) (Width x Height x Channels)
#    (3009, 1273, 3) (Width x Height x Channels)
#    (1412, 740, 3) (Width x Height x Channels)
#    (3029, 1382, 3) (Width x Height x Channels)
#    (2028, 864, 3) (Width x Height x Channels)
#    (1724, 1048, 3) (Width x Height x Channels)
#    (1680, 836, 3) (Width x Height x Channels)
#    (3016, 1397, 3) (Width x Height x Channels)
#    (1524, 788, 3) (Width x Height x Channels)
#    (2460, 1172, 3) (Width x Height x Channels)
#    (1356, 556, 3) (Width x Height x Channels)
#    (1468, 704, 3) (Width x Height x Channels)
#    (3000, 1334, 3) (Width x Height x Channels)
#    (1276, 540, 3) (Width x Height x Channels)
#    (1896, 796, 3) (Width x Height x Channels)
#    (2804, 1749, 3) (Width x Height x Channels)
#    (1504, 780, 3) (Width x Height x Channels)
#    (2116, 872, 3) (Width x Height x Channels)
#    (3009, 1303, 3) (Width x Height x Channels)
#    (1452, 616, 3) (Width x Height x Channels)
#    (2000, 892, 3) (Width x Height x Channels)
#    (1884, 824, 3) (Width x Height x Channels)
#    (1380, 552, 3) (Width x Height x Channels)
#    (1208, 512, 3) (Width x Height x Channels)
#    (3019, 1281, 3) (Width x Height x Channels)
#    (3004, 1330, 3) (Width x Height x Channels)
#    (2180, 1084, 3) (Width x Height x Channels)
#    (3000, 1538, 3) (Width x Height x Channels)
#    (3032, 1890, 3) (Width x Height x Channels)
#    (3000, 1276, 3) (Width x Height x Channels)
#    (3007, 1437, 3) (Width x Height x Channels)
#    (1944, 808, 3) (Width x Height x Channels)
#    (2408, 1172, 3) (Width x Height x Channels)
#    (1860, 884, 3) (Width x Height x Channels)
#    (1464, 752, 3) (Width x Height x Channels)
#    (3152, 1292, 3) (Width x Height x Channels)
#    (2340, 1153, 3) (Width x Height x Channels)
#    (3000, 1751, 3) (Width x Height x Channels)
#    (3000, 1489, 3) (Width x Height x Channels)
#    (3007, 1254, 3) (Width x Height x Channels)
#    (3000, 1227, 3) (Width x Height x Channels)
#    (1880, 984, 3) (Width x Height x Channels)
#    (1844, 796, 3) (Width x Height x Channels)
#    (2196, 1028, 3) (Width x Height x Channels)
#    (1476, 800, 3) (Width x Height x Channels)
#    (2340, 1104, 3) (Width x Height x Channels)
#    (3000, 1306, 3) (Width x Height x Channels)
#    (3000, 1702, 3) (Width x Height x Channels)
#    (1412, 588, 3) (Width x Height x Channels)
#    (3000, 1440, 3) (Width x Height x Channels)
#    (1864, 896, 3) (Width x Height x Channels)
#    (3033, 1375, 3) (Width x Height x Channels)
#    (3070, 1404, 3) (Width x Height x Channels)
#    (3008, 1293, 3) (Width x Height x Channels)
#    (3016, 1274, 3) (Width x Height x Channels)
#    (3011, 1300, 3) (Width x Height x Channels)
#    (3028, 1330, 3) (Width x Height x Channels)
#    (1936, 836, 3) (Width x Height x Channels)
#    (1812, 944, 3) (Width x Height x Channels)
#    (1816, 1148, 3) (Width x Height x Channels)
#    (2084, 972, 3) (Width x Height x Channels)
#    (3014, 1392, 3) (Width x Height x Channels)
#    (3020, 1865, 3) (Width x Height x Channels)
#    (1756, 760, 3) (Width x Height x Channels)
#    (3013, 1267, 3) (Width x Height x Channels)
#    (2468, 1036, 3) (Width x Height x Channels)
#    (1416, 600, 3) (Width x Height x Channels)
#    (2188, 1068, 3) (Width x Height x Channels)
#    (3012, 1314, 3) (Width x Height x Channels)
#    (1560, 804, 3) (Width x Height x Channels)
#    (3107, 1360, 3) (Width x Height x Channels)
#    (1608, 724, 3) (Width x Height x Channels)
#    (1440, 620, 3) (Width x Height x Channels)
#    (1280, 512, 3) (Width x Height x Channels)
#    (1652, 828, 3) (Width x Height x Channels)
#    (1468, 716, 3) (Width x Height x Channels)
#    (3027, 1369, 3) (Width x Height x Channels)
#    (3000, 1683, 3) (Width x Height x Channels)
#    (3000, 1287, 3) (Width x Height x Channels)
#    (1260, 504, 3) (Width x Height x Channels)
#    (1572, 812, 3) (Width x Height x Channels)
#    (1760, 732, 3) (Width x Height x Channels)
#    (1128, 476, 3) (Width x Height x Channels)
#    (3043, 1353, 3) (Width x Height x Channels)
#    (3000, 1500, 3) (Width x Height x Channels)
#    (1792, 1100, 3) (Width x Height x Channels)
#    (1116, 688, 3) (Width x Height x Channels)
#    (2416, 1348, 3) (Width x Height x Channels)
#    (2808, 1164, 3) (Width x Height x Channels)
#    (2612, 1192, 3) (Width x Height x Channels)
#    (2024, 836, 3) (Width x Height x Channels)
#    (1444, 592, 3) (Width x Height x Channels)
#    (3000, 1288, 3) (Width x Height x Channels)
#    (1820, 828, 3) (Width x Height x Channels)
#    (1384, 600, 3) (Width x Height x Channels)
#    (1660, 1044, 3) (Width x Height x Channels)
#    (3036, 1314, 3) (Width x Height x Channels)
#    (3260, 1360, 3) (Width x Height x Channels)
#    (2240, 1080, 3) (Width x Height x Channels)
#    (1816, 908, 3) (Width x Height x Channels)
#    (2504, 1184, 3) (Width x Height x Channels)
#    (1376, 564, 3) (Width x Height x Channels)
#    (2628, 1176, 3) (Width x Height x Channels)
#    (3000, 1367, 3) (Width x Height x Channels)
#    (1412, 724, 3) (Width x Height x Channels)
#    (2696, 1308, 3) (Width x Height x Channels)
#    (2028, 848, 3) (Width x Height x Channels)
#    (2934, 1398, 3) (Width x Height x Channels)
#    (2108, 924, 3) (Width x Height x Channels)
#    (3024, 1287, 3) (Width x Height x Channels)
#    (1252, 632, 3) (Width x Height x Channels)
#    (3592, 1584, 3) (Width x Height x Channels)
#    (3012, 1415, 3) (Width x Height x Channels)
#    (3000, 1318, 3) (Width x Height x Channels)
#    (1580, 736, 3) (Width x Height x Channels)
#    (3033, 1253, 3) (Width x Height x Channels)
#    (3016, 1198, 3) (Width x Height x Channels)
#    (1352, 708, 3) (Width x Height x Channels)
#    (3007, 1470, 3) (Width x Height x Channels)
#    (1540, 628, 3) (Width x Height x Channels)
#    (1232, 524, 3) (Width x Height x Channels)
#    (1300, 544, 3) (Width x Height x Channels)
#    (2000, 876, 3) (Width x Height x Channels)
#    (3053, 1549, 3) (Width x Height x Channels)
#    (3023, 1438, 3) (Width x Height x Channels)
#    (1168, 516, 3) (Width x Height x Channels)
#    (3001, 1781, 3) (Width x Height x Channels)
#    (3000, 1522, 3) (Width x Height x Channels)
#    (1756, 772, 3) (Width x Height x Channels)
#    (3000, 1260, 3) (Width x Height x Channels)
#    (3120, 1332, 3) (Width x Height x Channels)
#    (3000, 1348, 3) (Width x Height x Channels)
#    (1860, 868, 3) (Width x Height x Channels)
#    (1392, 584, 3) (Width x Height x Channels)
#    (1544, 640, 3) (Width x Height x Channels)
#    (3000, 1473, 3) (Width x Height x Channels)
#    (1924, 812, 3) (Width x Height x Channels)
#    (2512, 1168, 3) (Width x Height x Channels)
#    (3176, 1296, 3) (Width x Height x Channels)
#    (1808, 916, 3) (Width x Height x Channels)
#    (3006, 1438, 3) (Width x Height x Channels)
#    (3083, 1423, 3) (Width x Height x Channels)
#    (1412, 572, 3) (Width x Height x Channels)
#    (3000, 1290, 3) (Width x Height x Channels)
#    (3080, 1266, 3) (Width x Height x Channels)
#    (1172, 488, 3) (Width x Height x Channels)
#    (2524, 1216, 3) (Width x Height x Channels)
#    (1468, 748, 3) (Width x Height x Channels)
#    (1436, 592, 3) (Width x Height x Channels)
#    (1544, 932, 3) (Width x Height x Channels)
#    (1772, 832, 3) (Width x Height x Channels)
#    (1432, 672, 3) (Width x Height x Channels)
#    (3000, 1899, 3) (Width x Height x Channels)
#    (3000, 1503, 3) (Width x Height x Channels)
#    (2552, 1240, 3) (Width x Height x Channels)
#    (3000, 1241, 3) (Width x Height x Channels)
#    (2148, 1256, 3) (Width x Height x Channels)
#    (1416, 584, 3) (Width x Height x Channels)
#    (1948, 868, 3) (Width x Height x Channels)
#    (3000, 1320, 3) (Width x Height x Channels)
#    (1164, 556, 3) (Width x Height x Channels)
#    (1440, 604, 3) (Width x Height x Channels)
#    (1132, 500, 3) (Width x Height x Channels)
#    (2340, 1159, 3) (Width x Height x Channels)
#    (3015, 1384, 3) (Width x Height x Channels)
#    (3000, 1533, 3) (Width x Height x Channels)
#    (3009, 1735, 3) (Width x Height x Channels)
#    (1428, 720, 3) (Width x Height x Channels)
#    (1888, 880, 3) (Width x Height x Channels)
#    (3023, 1237, 3) (Width x Height x Channels)
#    (1848, 872, 3) (Width x Height x Channels)
#    (3000, 1187, 3) (Width x Height x Channels)
#    (3000, 1321, 3) (Width x Height x Channels)
#    (1920, 824, 3) (Width x Height x Channels)
#    (1912, 900, 3) (Width x Height x Channels)
#    (3000, 1746, 3) (Width x Height x Channels)
#    (3005, 1245, 3) (Width x Height x Channels)
#    (1596, 816, 3) (Width x Height x Channels)
#    (1748, 872, 3) (Width x Height x Channels)
#    (3028, 1211, 3) (Width x Height x Channels)
#    (1984, 940, 3) (Width x Height x Channels)
#    (1308, 528, 3) (Width x Height x Channels)
#    (3000, 1871, 3) (Width x Height x Channels)
#    (1828, 864, 3) (Width x Height x Channels)
#    (3000, 1272, 3) (Width x Height x Channels)
#    (2340, 1189, 3) (Width x Height x Channels)
#    (1384, 584, 3) (Width x Height x Channels)
#    (1964, 1016, 3) (Width x Height x Channels)
#    (1852, 884, 3) (Width x Height x Channels)
#    (3040, 1259, 3) (Width x Height x Channels)
#    (1376, 548, 3) (Width x Height x Channels)
#    (1688, 856, 3) (Width x Height x Channels)
#    (3017, 1381, 3) (Width x Height x Channels)
#    (1612, 1012, 3) (Width x Height x Channels)
#    (3000, 1351, 3) (Width x Height x Channels)
#    (3021, 1426, 3) (Width x Height x Channels)
#    (2814, 1326, 3) (Width x Height x Channels)
#    (2340, 1140, 3) (Width x Height x Channels)
#    (2732, 1156, 3) (Width x Height x Channels)
# ...
#    (3023, 1136, 3) (Width x Height x Channels)
#    (2376, 1172, 3) (Width x Height x Channels)
#    (1480, 784, 3) (Width x Height x Channels)
#    (1976, 1204, 3) (Width x Height x Channels)
#    (2564, 1092, 3) (Width x Height x Channels)
#    (1944, 1148, 3) (Width x Height x Channels)
#    (2456, 1164, 3) (Width x Height x Channels)
#    (1900, 836, 3) (Width x Height x Channels)
#    (1984, 848, 3) (Width x Height x Channels)
#    (1373, 710, 3) (Width x Height x Channels)
#    (3080, 1225, 3) (Width x Height x Channels)
#    (3000, 1779, 3) (Width x Height x Channels)
#    (1408, 724, 3) (Width x Height x Channels)
#    (1664, 872, 3) (Width x Height x Channels)
#    (2596, 1124, 3) (Width x Height x Channels)
#    (2424, 1480, 3) (Width x Height x Channels)
#    (2748, 1180, 3) (Width x Height x Channels)
#    (3017, 1463, 3) (Width x Height x Channels)
#    (1424, 588, 3) (Width x Height x Channels)
#    (1964, 924, 3) (Width x Height x Channels)
#    (3035, 1272, 3) (Width x Height x Channels)
#    (1568, 792, 3) (Width x Height x Channels)
#    (1952, 1080, 3) (Width x Height x Channels)
#    (1412, 744, 3) (Width x Height x Channels)
#    (3034, 1281, 3) (Width x Height x Channels)
#    (1648, 784, 3) (Width x Height x Channels)
#    (3019, 1255, 3) (Width x Height x Channels)
#    (2372, 1132, 3) (Width x Height x Channels)
#    (1476, 744, 3) (Width x Height x Channels)
#    (1948, 836, 3) (Width x Height x Channels)
#    (3000, 1250, 3) (Width x Height x Channels)
#    (1356, 560, 3) (Width x Height x Channels)
#    (1976, 972, 3) (Width x Height x Channels)
#    (3014, 1385, 3) (Width x Height x Channels)
#    (2576, 1116, 3) (Width x Height x Channels)
#    (1944, 916, 3) (Width x Height x Channels)
#    (3025, 1791, 3) (Width x Height x Channels)
#    (3025, 1395, 3) (Width x Height x Channels)
#    (2840, 1220, 3) (Width x Height x Channels)
#    (3000, 1809, 3) (Width x Height x Channels)
#    (1504, 784, 3) (Width x Height x Channels)
#    (3000, 1463, 3) (Width x Height x Channels)
#    (1216, 552, 3) (Width x Height x Channels)
#    (3017, 1493, 3) (Width x Height x Channels)
#    (1376, 748, 3) (Width x Height x Channels)
#    (1872, 772, 3) (Width x Height x Channels)
#    (1884, 828, 3) (Width x Height x Channels)
#    (2008, 820, 3) (Width x Height x Channels)
#    (3044, 1738, 3) (Width x Height x Channels)
#    (1952, 848, 3) (Width x Height x Channels)
#    (3015, 1215, 3) (Width x Height x Channels)
#    (3324, 1360, 3) (Width x Height x Channels)
#    (2604, 1528, 3) (Width x Height x Channels)
#    (3000, 1676, 3) (Width x Height x Channels)
#    (3000, 1280, 3) (Width x Height x Channels)
#    (2128, 1320, 3) (Width x Height x Channels)
#    (3007, 1441, 3) (Width x Height x Channels)
#    (3000, 1414, 3) (Width x Height x Channels)
#    (1368, 584, 3) (Width x Height x Channels)
#    (2340, 1078, 3) (Width x Height x Channels)
#    (2112, 916, 3) (Width x Height x Channels)
#    (1944, 812, 3) (Width x Height x Channels)
#    (1520, 640, 3) (Width x Height x Channels)
#    (1664, 844, 3) (Width x Height x Channels)
#    (1320, 552, 3) (Width x Height x Channels)
#    (1392, 604, 3) (Width x Height x Channels)
#    (1544, 660, 3) (Width x Height x Channels)
#    (3152, 1296, 3) (Width x Height x Channels)
#    (3031, 1333, 3) (Width x Height x Channels)
#    (1281, 722, 3) (Width x Height x Channels)
#    (1684, 1016, 3) (Width x Height x Channels)
#    (2236, 1012, 3) (Width x Height x Channels)
#    (3010, 1312, 3) (Width x Height x Channels)
#    (1096, 548, 3) (Width x Height x Channels)
#    (2260, 1032, 3) (Width x Height x Channels)
#    (3164, 1344, 3) (Width x Height x Channels)
#    (1396, 600, 3) (Width x Height x Channels)
#    (1412, 592, 3) (Width x Height x Channels)
#    (3000, 1706, 3) (Width x Height x Channels)
#    (1920, 872, 3) (Width x Height x Channels)
#    (1364, 544, 3) (Width x Height x Channels)
#    (3000, 1444, 3) (Width x Height x Channels)
#    (2880, 1260, 3) (Width x Height x Channels)
#    (3032, 1316, 3) (Width x Height x Channels)
#    (3049, 1346, 3) (Width x Height x Channels)
#    (2640, 1176, 3) (Width x Height x Channels)
#    (3021, 1435, 3) (Width x Height x Channels)
#    (3017, 1262, 3) (Width x Height x Channels)
#    (3000, 1919, 3) (Width x Height x Channels)
#    (3000, 1657, 3) (Width x Height x Channels)
#    (3000, 1261, 3) (Width x Height x Channels)
#    (3029, 1918, 3) (Width x Height x Channels)
#    (3000, 1395, 3) (Width x Height x Channels)
#    (2500, 1096, 3) (Width x Height x Channels)
#    (2076, 924, 3) (Width x Height x Channels)
#    (3030, 1301, 3) (Width x Height x Channels)
#    (2852, 1328, 3) (Width x Height x Channels)
#    (2732, 1200, 3) (Width x Height x Channels)
#    (1416, 604, 3) (Width x Height x Channels)
#    (3037, 1425, 3) (Width x Height x Channels)
#    (3063, 1286, 3) (Width x Height x Channels)
#    (1860, 860, 3) (Width x Height x Channels)
#    (3000, 1474, 3) (Width x Height x Channels)
#    (1628, 812, 3) (Width x Height x Channels)
#    (2044, 1256, 3) (Width x Height x Channels)
#    (2020, 928, 3) (Width x Height x Channels)
#    (1620, 988, 3) (Width x Height x Channels)
#    (1712, 824, 3) (Width x Height x Channels)
#    (3010, 1293, 3) (Width x Height x Channels)
#    (3056, 1238, 3) (Width x Height x Channels)
#    (1952, 900, 3) (Width x Height x Channels)
#    (3000, 1812, 3) (Width x Height x Channels)
#    (2968, 1260, 3) (Width x Height x Channels)
#    (1372, 556, 3) (Width x Height x Channels)
#    (3033, 1410, 3) (Width x Height x Channels)
#    (2296, 1080, 3) (Width x Height x Channels)
#    (3020, 1425, 3) (Width x Height x Channels)
#    (1096, 480, 3) (Width x Height x Channels)
#    (1780, 948, 3) (Width x Height x Channels)
#    (2740, 1232, 3) (Width x Height x Channels)
#    (1328, 528, 3) (Width x Height x Channels)
#    (1856, 1104, 3) (Width x Height x Channels)
#    (2400, 1176, 3) (Width x Height x Channels)
#    (3000, 1292, 3) (Width x Height x Channels)
#    (2328, 1112, 3) (Width x Height x Channels)
#    (1352, 548, 3) (Width x Height x Channels)
#    (2124, 1016, 3) (Width x Height x Channels)
#    (1432, 624, 3) (Width x Height x Channels)
#    (3005, 1216, 3) (Width x Height x Channels)
#    (3168, 1316, 3) (Width x Height x Channels)
#    (2656, 1116, 3) (Width x Height x Channels)
#    (3156, 1472, 3) (Width x Height x Channels)
#    (3030, 1748, 3) (Width x Height x Channels)
#    (1524, 776, 3) (Width x Height x Channels)
#    (3006, 1516, 3) (Width x Height x Channels)
#    (3000, 1496, 3) (Width x Height x Channels)
#    (3088, 1300, 3) (Width x Height x Channels)
#    (2460, 1160, 3) (Width x Height x Channels)
#    (3007, 1261, 3) (Width x Height x Channels)
#    (3000, 1234, 3) (Width x Height x Channels)
#    (1252, 636, 3) (Width x Height x Channels)
#    (3062, 1355, 3) (Width x Height x Channels)
#    (1500, 748, 3) (Width x Height x Channels)
#    (1824, 844, 3) (Width x Height x Channels)
#    (2720, 1204, 3) (Width x Height x Channels)
#    (3000, 1322, 3) (Width x Height x Channels)
#    (1900, 900, 3) (Width x Height x Channels)
#    (1276, 528, 3) (Width x Height x Channels)
#    (1856, 788, 3) (Width x Height x Channels)
#    (3000, 1709, 3) (Width x Height x Channels)
#    (2340, 1111, 3) (Width x Height x Channels)
#    (1504, 768, 3) (Width x Height x Channels)
#    (3000, 1447, 3) (Width x Height x Channels)
#    (1540, 632, 3) (Width x Height x Channels)
#    (3154, 1345, 3) (Width x Height x Channels)
#    (3001, 1226, 3) (Width x Height x Channels)
#    (2280, 1044, 3) (Width x Height x Channels)
#    (1528, 788, 3) (Width x Height x Channels)
#    (1804, 836, 3) (Width x Height x Channels)
#    (1532, 730, 3) (Width x Height x Channels)
#    (2180, 1072, 3) (Width x Height x Channels)
#    (3033, 1208, 3) (Width x Height x Channels)
#    (3000, 1526, 3) (Width x Height x Channels)
#    (1136, 464, 3) (Width x Height x Channels)
#    (3003, 1355, 3) (Width x Height x Channels)
#    (3000, 1264, 3) (Width x Height x Channels)
#    (2096, 1248, 3) (Width x Height x Channels)
#    (1328, 588, 3) (Width x Height x Channels)
#    (2376, 1004, 3) (Width x Height x Channels)
#    (1320, 536, 3) (Width x Height x Channels)
#    (1576, 700, 3) (Width x Height x Channels)
#    (2520, 1208, 3) (Width x Height x Channels)
#    (1392, 588, 3) (Width x Height x Channels)
#    (1980, 872, 3) (Width x Height x Channels)
#    (1348, 672, 3) (Width x Height x Channels)
#    (2132, 900, 3) (Width x Height x Channels)
#    (1964, 796, 3) (Width x Height x Channels)
#    (3000, 1477, 3) (Width x Height x Channels)
#    (2312, 996, 3) (Width x Height x Channels)
#    (1300, 540, 3) (Width x Height x Channels)
#    (3140, 1436, 3) (Width x Height x Channels)
#    (3000, 1215, 3) (Width x Height x Channels)
#    (1816, 844, 3) (Width x Height x Channels)
#    (3055, 1337, 3) (Width x Height x Channels)
#    (2744, 1204, 3) (Width x Height x Channels)
#    (3027, 1722, 3) (Width x Height x Channels)
#    (1608, 1028, 3) (Width x Height x Channels)
#    (2188, 1288, 3) (Width x Height x Channels)
#    (3200, 1320, 3) (Width x Height x Channels)
#    (1328, 792, 3) (Width x Height x Channels)
#    (1396, 712, 3) (Width x Height x Channels)
#    (1280, 644, 3) (Width x Height x Channels)
#    (3000, 1690, 3) (Width x Height x Channels)
#    (1412, 576, 3) (Width x Height x Channels)
#    (3000, 1294, 3) (Width x Height x Channels)
#    (3038, 1386, 3) (Width x Height x Channels)
#    (3000, 1428, 3) (Width x Height x Channels)
#    (1172, 492, 3) (Width x Height x Channels)
#    (1472, 768, 3) (Width x Height x Channels)
#    (1864, 884, 3) (Width x Height x Channels)
#    (2960, 1448, 3) (Width x Height x Channels)
#    (1468, 752, 3) (Width x Height x Channels)
#    (1112, 500, 3) (Width x Height x Channels)
#    (1772, 836, 3) (Width x Height x Channels)
#    (3000, 1903, 3) (Width x Height x Channels)
#    (3041, 1266, 3) (Width x Height x Channels)
#    (3000, 1245, 3) (Width x Height x Channels)
#    (1932, 904, 3) (Width x Height x Channels)
#    (2851, 1196, 3) (Width x Height x Channels)
#    (1924, 852, 3) (Width x Height x Channels)
#    (3026, 1889, 3) (Width x Height x Channels)
#    (3019, 1291, 3) (Width x Height x Channels)
#    (1208, 560, 3) (Width x Height x Channels)
#    (3062, 1357, 3) (Width x Height x Channels)
#    (3280, 1388, 3) (Width x Height x Channels)
#    (1440, 608, 3) (Width x Height x Channels)
#    (2800, 1332, 3) (Width x Height x Channels)
#    (1672, 712, 3) (Width x Height x Channels)
#    (3000, 1112, 3) (Width x Height x Channels)
#    (1908, 780, 3) (Width x Height x Channels)
#    (3000, 1246, 3) (Width x Height x Channels)
#    (3011, 1318, 3) (Width x Height x Channels)
#    (3036, 1272, 3) (Width x Height x Channels)
#    (1296, 792, 3) (Width x Height x Channels)
#    (1848, 788, 3) (Width x Height x Channels)
#    (2008, 856, 3) (Width x Height x Channels)
#    (3000, 1325, 3) (Width x Height x Channels)
#    (3010, 1356, 3) (Width x Height x Channels)
#    (1612, 724, 3) (Width x Height x Channels)
#    (1549, 812, 3) (Width x Height x Channels)
#    (1836, 904, 3) (Width x Height x Channels)
#    (1128, 464, 3) (Width x Height x Channels)
#    (2920, 1284, 3) (Width x Height x Channels)
#    (3244, 1380, 3) (Width x Height x Channels)
#    (3156, 1252, 3) (Width x Height x Channels)
#    (1272, 540, 3) (Width x Height x Channels)
#    (3000, 1875, 3) (Width x Height x Channels)
#    (1660, 1032, 3) (Width x Height x Channels)
#    (2328, 1096, 3) (Width x Height x Channels)
#    (1200, 476, 3) (Width x Height x Channels)
#    (1372, 744, 3) (Width x Height x Channels)
#    (1408, 608, 3) (Width x Height x Channels)
#    (1684, 1052, 3) (Width x Height x Channels)
#    (2748, 1148, 3) (Width x Height x Channels)
#    (3016, 1244, 3) (Width x Height x Channels)
#    (1812, 780, 3) (Width x Height x Channels)
#    (1764, 732, 3) (Width x Height x Channels)
#    (2620, 1112, 3) (Width x Height x Channels)
#    (1956, 856, 3) (Width x Height x Channels)
#    (2340, 1144, 3) (Width x Height x Channels)
#    (1628, 856, 3) (Width x Height x Channels)
#    (2016, 952, 3) (Width x Height x Channels)
#    (3054, 1540, 3) (Width x Height x Channels)
#    (1688, 1064, 3) (Width x Height x Channels)
#    (3000, 1559, 3) (Width x Height x Channels)
#    (3014, 1298, 3) (Width x Height x Channels)
#    (1620, 820, 3) (Width x Height x Channels)
#    (2348, 1076, 3) (Width x Height x Channels)
#    (1884, 924, 3) (Width x Height x Channels)
#    (2120, 1048, 3) (Width x Height x Channels)
#    (1376, 716, 3) (Width x Height x Channels)
#    (1872, 1136, 3) (Width x Height x Channels)
#    (1608, 848, 3) (Width x Height x Channels)
#    (1256, 532, 3) (Width x Height x Channels)
#    (1948, 924, 3) (Width x Height x Channels)
#    (3000, 1772, 3) (Width x Height x Channels)
#    (3004, 1302, 3) (Width x Height x Channels)
#    (3204, 1344, 3) (Width x Height x Channels)
#    (1552, 792, 3) (Width x Height x Channels)
#    (3020, 1207, 3) (Width x Height x Channels)
#    (3000, 1644, 3) (Width x Height x Channels)
#    (2416, 1096, 3) (Width x Height x Channels)
#    (2960, 1268, 3) (Width x Height x Channels)
#    (1776, 1072, 3) (Width x Height x Channels)
#    (1248, 496, 3) (Width x Height x Channels)
#    (1732, 1072, 3) (Width x Height x Channels)
#    (3012, 1305, 3) (Width x Height x Channels)
#    (3044, 1305, 3) (Width x Height x Channels)
#    (1236, 524, 3) (Width x Height x Channels)
#    (3000, 1327, 3) (Width x Height x Channels)
#    (3000, 1857, 3) (Width x Height x Channels)
#    (3000, 1461, 3) (Width x Height x Channels)
#    (3030, 1367, 3) (Width x Height x Channels)
#    (3018, 1270, 3) (Width x Height x Channels)
#    (3021, 1848, 3) (Width x Height x Channels)
#    (2452, 1164, 3) (Width x Height x Channels)
#    (2188, 1272, 3) (Width x Height x Channels)
#    (3025, 1260, 3) (Width x Height x Channels)
#    (2260, 1000, 3) (Width x Height x Channels)
#    (3000, 1540, 3) (Width x Height x Channels)
#    (3000, 1278, 3) (Width x Height x Channels)
#    (3014, 1279, 3) (Width x Height x Channels)
#    (1588, 820, 3) (Width x Height x Channels)
#    (3108, 1256, 3) (Width x Height x Channels)
#    (1444, 632, 3) (Width x Height x Channels)
#    (1036, 640, 3) (Width x Height x Channels)
#    (1944, 860, 3) (Width x Height x Channels)
#    (1348, 552, 3) (Width x Height x Channels)
#    (3033, 1397, 3) (Width x Height x Channels)
#    (3144, 1332, 3) (Width x Height x Channels)
#    (1624, 996, 3) (Width x Height x Channels)
#    (1432, 660, 3) (Width x Height x Channels)
#    (1732, 840, 3) (Width x Height x Channels)
#    (3000, 1753, 3) (Width x Height x Channels)
#    (3018, 1608, 3) (Width x Height x Channels)
#    (1504, 812, 3) (Width x Height x Channels)
#    (2596, 1144, 3) (Width x Height x Channels)
#    (2396, 1380, 3) (Width x Height x Channels)
#    (3000, 1279, 3) (Width x Height x Channels)
#    (1436, 784, 3) (Width x Height x Channels)
#    (1916, 800, 3) (Width x Height x Channels)
#    (3000, 1704, 3) (Width x Height x Channels)
#    (3000, 1308, 3) (Width x Height x Channels)
#    (2568, 1608, 3) (Width x Height x Channels)
#    (1440, 592, 3) (Width x Height x Channels)
#    (3011, 1738, 3) (Width x Height x Channels)
#    (1200, 508, 3) (Width x Height x Channels)
#    (3096, 1189, 3) (Width x Height x Channels)
#    (2644, 1268, 3) (Width x Height x Channels)
#    (1152, 572, 3) (Width x Height x Channels)
#    (2340, 1147, 3) (Width x Height x Channels)
#    (3035, 1322, 3) (Width x Height x Channels)
#    (1292, 532, 3) (Width x Height x Channels)
#    (3012, 1406, 3) (Width x Height x Channels)
#    (3013, 1269, 3) (Width x Height x Channels)
#    (3000, 1309, 3) (Width x Height x Channels)
#    (2896, 1376, 3) (Width x Height x Channels)
#    (3001, 1821, 3) (Width x Height x Channels)
#    (1596, 804, 3) (Width x Height x Channels)
#    (3108, 1316, 3) (Width x Height x Channels)
#    (3076, 1260, 3) (Width x Height x Channels)
#    (1785, 827, 3) (Width x Height x Channels)
#    (3001, 1251, 3) (Width x Height x Channels)
#    (3022, 1313, 3) (Width x Height x Channels)
#    (2320, 1068, 3) (Width x Height x Channels)
#    (3070, 1436, 3) (Width x Height x Channels)
#    (3045, 1292, 3) (Width x Height x Channels)
#    (1384, 572, 3) (Width x Height x Channels)
#    (1820, 800, 3) (Width x Height x Channels)
#    (3000, 1513, 3) (Width x Height x Channels)
#    (1408, 592, 3) (Width x Height x Channels)
#    (3168, 1546, 3) (Width x Height x Channels)
#    (3000, 1339, 3) (Width x Height x Channels)

# %%
# Root folder with subfolders per class
dataset_path = root_folder
target_size = (224, 224)  # width, height

print("Resizing all images to 224x224...")

for cls in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, cls)
    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)

            # Read image
            img = cv2.imread(img_path)
            if img is not None:
                # Resize
                resized_img = cv2.resize(img, target_size)
                # Overwrite the original image with resized one
                cv2.imwrite(img_path, resized_img)

print("✅ All images resized to 224x224.")
# Out:
# Resizing all images to 224x224...
# ✅ All images resized to 224x224.

# %%
# Select any class and one image
classes = [d for d in os.listdir(root_folder) if os.path.isdir(os.path.join(root_folder, d))]
selected_class = random.choice(classes)
img_name = random.choice(os.listdir(os.path.join(root_folder, selected_class)))
img_path = os.path.join(root_folder, selected_class, img_name)

# Read original image
original_img = cv2.imread(img_path)
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
original_size = original_img.shape[:2]  # height, width

# Resize image
target_size = (224, 224)
resized_img = cv2.resize(original_img, target_size)
resized_size = resized_img.shape[:2]  # height, width

# Plot original vs resized with sizes in title
plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(original_img)
plt.title(f'Original: {original_size[1]}x{original_size[0]}', fontsize=14, fontweight='bold')  # width x height
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(resized_img)
plt.title(f'Resized: {resized_size[1]}x{resized_size[0]}', fontsize=14, fontweight='bold')  # width x height
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 📌 Step 4: Split Dataset into Train, Validation, and Test

# %% [markdown]
# ##### 🔹 **Split Dataset**
# - Divide images into Train, Validation, and Test sets (.g., `70:15:15` or `80:10:10`).
# - Create new directories and copy images into the respective folders.

# %%
# Original dataset path (with subfolders per class)
original_dataset = root_folder  # your root folder

# Path to split folder (will be created under the root folder)
split_dataset = os.path.join(root_folder, "split")

# Remove previous split folder if it exists
if os.path.exists(split_dataset):
    shutil.rmtree(split_dataset)

# Create new split folder
os.makedirs(split_dataset)

# Split ratios
train_ratio, val_ratio, test_ratio = 0.7, 0.15, 0.15

print("🔄 Splitting dataset into train/val/test...")

# Iterate only over actual class folders (ignore any existing 'split' folder)
for class_name in os.listdir(original_dataset):
    class_path = os.path.join(original_dataset, class_name)
    if not os.path.isdir(class_path) or class_name == "split":
        continue  # skip non-folders and split folder itself

    # List all files in the class folder
    imgs = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
    random.shuffle(imgs)

    n_total = len(imgs)
    n_train = math.floor(train_ratio * n_total)
    n_val   = math.floor(val_ratio * n_total)

    split_imgs = {
        "train": imgs[:n_train],
        "val": imgs[n_train:n_train+n_val],
        "test": imgs[n_train+n_val:]
    }

    # Copy images to their respective split folders
    for split, files in split_imgs.items():
        split_class_path = os.path.join(split_dataset, split, class_name)
        os.makedirs(split_class_path, exist_ok=True)

        for f in tqdm(files, desc=f"{class_name}-{split}"):
            src_path = os.path.join(class_path, f)
            dst_path = os.path.join(split_class_path, f)
            shutil.copy2(src_path, dst_path)  # copy file, preserve metadata

print("✅ Dataset successfully split into train/val/test at:", split_dataset)
# Out:
# 🔄 Splitting dataset into train/val/test...
# 10-train: 100%|██████████| 280/280 [00:04<00:00, 68.94it/s]
# 10-val: 100%|██████████| 60/60 [00:00<00:00, 90.86it/s]
# 10-test: 100%|██████████| 60/60 [00:00<00:00, 85.93it/s]
# 100-train: 100%|██████████| 280/280 [00:04<00:00, 59.27it/s]
# 100-val: 100%|██████████| 60/60 [00:00<00:00, 87.50it/s]
# 100-test: 100%|██████████| 60/60 [00:00<00:00, 89.77it/s]
# 1000-train: 100%|██████████| 280/280 [00:04<00:00, 60.11it/s]
# 1000-val: 100%|██████████| 60/60 [00:00<00:00, 90.58it/s]
# 1000-test: 100%|██████████| 60/60 [00:00<00:00, 86.06it/s]
# 2-train: 100%|██████████| 280/280 [00:04<00:00, 57.21it/s]
# 2-val: 100%|██████████| 60/60 [00:00<00:00, 62.73it/s]
# 2-test: 100%|██████████| 60/60 [00:00<00:00, 65.70it/s]
# 20-train: 100%|██████████| 280/280 [00:03<00:00, 85.29it/s]
# 20-val: 100%|██████████| 60/60 [00:00<00:00, 86.57it/s]
# 20-test: 100%|██████████| 60/60 [00:00<00:00, 73.55it/s]
# 200-train: 100%|██████████| 280/280 [00:03<00:00, 78.54it/s]
# 200-val: 100%|██████████| 60/60 [00:00<00:00, 73.76it/s]
# 200-test: 100%|██████████| 60/60 [00:00<00:00, 77.77it/s]
# 5-train: 100%|██████████| 280/280 [00:03<00:00, 79.16it/s]
# 5-val: 100%|██████████| 60/60 [00:00<00:00, 86.05it/s]
# 5-test: 100%|██████████| 60/60 [00:00<00:00, 81.62it/s]
# 50-train: 100%|██████████| 280/280 [00:03<00:00, 84.06it/s]
# 50-val: 100%|██████████| 60/60 [00:00<00:00, 81.73it/s]
# 50-test: 100%|██████████| 60/60 [00:00<00:00, 84.21it/s]
# 500-train: 100%|██████████| 280/280 [00:03<00:00, 79.93it/s]
# 500-val: 100%|██████████| 60/60 [00:00<00:00, 77.17it/s]
# 500-test: 100%|██████████| 60/60 [00:00<00:00, 75.00it/s]
# ✅ Dataset successfully split into train/val/test at: /content/drive/MyDrive/Bengali_Taka/BP/BP_F/split

# %% [markdown]
# ##### 🔹 **Visualize Splits**
# * Plot a **pie chart** showing the proportion of images in Train, Validation, and Test sets.

# %%
# Print counts per folder
print("\n📊 Dataset distribution after splitting:")
for split in ["train", "val", "test"]:
    total = 0
    print(f"\n{split.upper()}:")
    split_path = os.path.join(split_dataset, split)
    for class_name in os.listdir(split_path):
        count = len(os.listdir(os.path.join(split_path, class_name)))
        total += count
        print(f"   {class_name}: {count}")
    print(f"   Total {split}: {total}")
# Out:
# 📊 Dataset distribution after splitting:
#
# TRAIN:
#    10: 280
#    100: 280
#    1000: 280
#    2: 280
#    20: 280
#    200: 280
#    5: 280
#    50: 280
#    500: 280
#    Total train: 2520
#
# VAL:
#    10: 60
#    100: 60
#    1000: 60
#    2: 60
#    20: 60
#    200: 60
#    5: 60
#    50: 60
#    500: 60
#    Total val: 540
#
# TEST:
#    10: 60
#    100: 60
#    1000: 60
#    2: 60
#    20: 60
#    200: 60
#    5: 60
#    50: 60
#    500: 60
#    Total test: 540

# %%
# Data for the pie chart
#labels = ['Training (70%)', 'Validation (20%)', 'Testing (10%)']
#sizes = [70, 20, 10]

labels = ['Training (80%)', 'Validation (10%)', 'Testing (10%)']
sizes= [80,10,10]

colors = ['teal', '#2196F3', 'coral' ]  # Green, Blue, Orange
explode = (0.05, 0.05, 0.05)  # Slightly separate each section

# Plotting
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, explode=explode,
        autopct='%1.1f%%', shadow=True, startangle=140, textprops={'fontsize': 12, 'fontweight': 'bold'})
plt.title('Dataset Split Distribution', fontweight='bold')
plt.show()

# %% [markdown]
# ##### 🔹 **Folder Structure**
# Visualize the directory structure of the split dataset to verify class organization.

# %% [markdown]
# ```text
# root_folder/
# ├── train/
# │   ├── class_1/
# │   └── class_2/
# ├── validation/
# │   ├── class_1/
# │   └── class_2/
# └── test/
#     ├── class_1/
#     └── class_2/

# %% [markdown]
# # 📌 Step 5: Augment Training Data

# %% [markdown]
# ##### 🔹 **Apply Augmentations**
# * Perform image augmentations such as rotation, shift, zoom, flip, and shear.
# * Save augmented images in a separate folder: `aug_train/`.
# *  Count the number of images per class after augmentation.

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# Paths
train_path = os.path.join(split_dataset, 'train')
aug_root = os.path.join(original_dataset, 'aug_train')
os.makedirs(aug_root, exist_ok=True)

# Define augmentation parameters
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Allowed image extensions
valid_exts = ('.jpg', '.jpeg', '.png', '.bmp')

# Loop through each class folder
for cls in os.listdir(train_path):
    cls_path = os.path.join(train_path, cls)
    aug_cls_path = os.path.join(aug_root, cls)
    os.makedirs(aug_cls_path, exist_ok=True)

    original_images = [f for f in os.listdir(cls_path) if f.lower().endswith(valid_exts)]
    n_original = len(original_images)
    n_aug_per_img = 2 # 2 augmentations per image

    print(f"Augmenting class '{cls}': {n_original} originals → {n_original * n_aug_per_img} augmented images total")

    # Augment each image
    for img_name in original_images:
        img_path = os.path.join(cls_path, img_name)
        try:
            img = load_img(img_path, target_size=(224, 224))
            x = img_to_array(img)
            x = x.reshape((1,) + x.shape)

            i = 0
            for batch in datagen.flow(x, batch_size=1, save_to_dir=aug_cls_path,
                                      save_prefix='aug', save_format='jpg'):
                i += 1
                if i >= n_aug_per_img:  # stop after 3 augmentations per image
                    break

        except Exception as e:
            print(f"⚠️ Skipped '{img_name}' due to error: {e}")
# Out:
# Augmenting class '10': 280 originals → 560 augmented images total
# Augmenting class '100': 280 originals → 560 augmented images total
# Augmenting class '1000': 280 originals → 560 augmented images total
# Augmenting class '2': 280 originals → 560 augmented images total
# Augmenting class '20': 280 originals → 560 augmented images total
# Augmenting class '200': 280 originals → 560 augmented images total
# Augmenting class '5': 280 originals → 560 augmented images total
# Augmenting class '50': 280 originals → 560 augmented images total
# Augmenting class '500': 280 originals → 560 augmented images total

# %% [markdown]
# ##### 🔹 **Visualize Distribution**
# * Plot a **bar chart** comparing class balance **before and after** augmentation.

# %%
# Count images in augmented train folders
aug_counts = {cls: len(os.listdir(os.path.join(aug_root, cls))) for cls in class_names}

plt.figure(figsize=(13,7))

# Generate distinct colors for each bar
colors = plt.cm.tab20(np.arange(len(aug_counts)))

bars = plt.bar(aug_counts.keys(), aug_counts.values(), color=colors)

plt.title('Augmented Training Data Distribution', fontsize=16, fontweight='bold')
plt.ylabel('Number of Images', fontsize=14, fontweight='bold')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12)

# Add value labels on each bar
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,   # X position (center of the bar)
        height,                              # Y position (top of the bar)
        f'{int(height)}',                    # The text (convert to int)
        ha='center', va='bottom',            # Centered alignment
        fontsize=12, fontweight='bold', color='black'
    )

plt.show()

# %% [markdown]
# # 📌 Step 6: Comparison Section

# %% [markdown]
# ##### 🔹 **Compare Counts**
# * Compare the number of images in the original Train set versus the augmented Train set.
# * **Visualize differences** in dataset size across classes.
# * Ensure **uniform class balance** after augmentation.

# %%
# Paths
train_folder = os.path.join(split_dataset, "train")  # original train split
aug_folder   = os.path.join(root_folder, "aug_train")  # augmented train folder

# Get list of classes (assumes both folders have same class names)
classes = sorted([c for c in os.listdir(train_folder) if os.path.isdir(os.path.join(train_folder, c))])

# Count images per class
train_counts = [len(os.listdir(os.path.join(train_folder, c))) for c in classes]
aug_counts   = [len(os.listdir(os.path.join(aug_folder, c))) for c in classes]

# Plot side-by-side bar chart
x = np.arange(len(classes))  # the label locations
width = 0.35  # width of the bars

fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width/2, train_counts, width, label='Train', color='skyblue')
rects2 = ax.bar(x + width/2, aug_counts, width, label='Augmented Train', color='salmon')

# Add labels, title, and custom x-axis tick labels
ax.set_ylabel('Number of Images', fontsize=12, fontweight='bold')
ax.set_xlabel('Classes', fontsize=12, fontweight='bold')
ax.set_title('Comparison: Original Train vs Augmented Train', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(classes, rotation=45, fontsize=11, fontweight='bold')
ax.legend(fontsize=12)

# Add number labels on each bar
for rects in [rects1, rects2]:
    for rect in rects:
        height = rect.get_height()
        ax.text(
            rect.get_x() + rect.get_width()/2, height,
            f'{int(height)}',
            ha='center', va='bottom',
            fontsize=11, fontweight='bold', color='black'
        )

plt.tight_layout()
plt.show()

# %% [markdown]
# # 📌 Step 7: Denoise Training Data Only

# %% [markdown]
# ##### 🔹 **Denoising**
# * Apply filters like **Median or Gaussian** to reduce image noise.

# %%
from tqdm import tqdm

# Path to augmented training images
aug_root = os.path.join(root_folder, "aug_train")  # your aug_train folder

print("🔄 Denoising augmented images...")

# Loop through each class subfolder
for cls in os.listdir(aug_root):
    class_path = os.path.join(aug_root, cls)
    if not os.path.isdir(class_path):
        continue  # skip non-folder files

    # Loop through each image file in the class folder
    for img_name in tqdm(os.listdir(class_path), desc=f"Filtering {cls}"):
        img_path = os.path.join(class_path, img_name)

        # Read the image
        img = cv2.imread(img_path)

        if img is not None:
            try:
                # Apply median filter (kernel size = 3 or 5)
                filtered = cv2.bilateralFilter(img, 9, 75, 75)

                # Overwrite the original image
                cv2.imwrite(img_path, filtered)

            except Exception as e:
                print(f"⚠️ Skipped {img_name} due to error: {e}")
        else:
            print(f"⚠️ Skipped {img_name}: cannot read image")

print("✅ All augmented images successfully filtered and originals replaced.")
# Out:
# 🔄 Denoising augmented images...
# Filtering 10: 100%|██████████| 540/540 [00:13<00:00, 40.03it/s]
# Filtering 100: 100%|██████████| 547/547 [00:13<00:00, 41.12it/s]
# Filtering 1000: 100%|██████████| 547/547 [00:13<00:00, 41.66it/s]
# Filtering 2: 100%|██████████| 541/541 [00:12<00:00, 42.57it/s]
# Filtering 20: 100%|██████████| 536/536 [00:12<00:00, 42.40it/s]
# Filtering 200: 100%|██████████| 542/542 [00:12<00:00, 41.85it/s]
# Filtering 5: 100%|██████████| 549/549 [00:13<00:00, 41.73it/s]
# Filtering 50: 100%|██████████| 542/542 [00:12<00:00, 42.15it/s]
# Filtering 500: 100%|██████████| 549/549 [00:13<00:00, 42.03it/s]
# ✅ All augmented images successfully filtered and originals replaced.

# %% [markdown]
# ##### 🔹 **Save Images**
# * Store denoised images in the same training data folder.

# %%
# Path to augmented images
aug_root = os.path.join(root_folder, "aug_train")  # your augmented folder

# Choose a random class and image
cls = random.choice([c for c in os.listdir(aug_root) if os.path.isdir(os.path.join(aug_root, c))])
class_path = os.path.join(aug_root, cls)
img_name = random.choice(os.listdir(class_path))
img_path = os.path.join(class_path, img_name)

# Read original image
original_img = cv2.imread(img_path)
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

# Apply denoising (for demonstration)
denoised_img = cv2.fastNlMeansDenoisingColored(original_img, None, h=10, hColor=10, templateWindowSize=7, searchWindowSize=21)

# Plot side by side
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(original_img)
plt.title(f"Original: {cls}/{img_name}", fontsize=12, fontweight='bold')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(denoised_img)
plt.title(f"Denoised: {cls}/{img_name}", fontsize=12, fontweight='bold')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import os
from PIL import Image, UnidentifiedImageError

# 🔹 Set your image directory
root_dir = "/content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/aug_train"  # <-- change this

deleted_count = 0

for dirpath, dirnames, filenames in os.walk(root_dir):
    for fname in filenames:
        fpath = os.path.join(dirpath, fname)

        # Skip hidden/system files
        if fname.startswith('.'):
            continue

        try:
            with Image.open(fpath) as img:
                img.verify()  # check if file is a valid image
        except (UnidentifiedImageError, OSError, ValueError):
            os.remove(fpath)  # delete corrupted file
            deleted_count += 1
            print(f"🗑️ Deleted corrupted image: {fpath}")

print(f"\n✅ Done. Deleted {deleted_count} corrupted images from {root_dir}")
# Out:
# ✅ Done. Deleted 0 corrupted images from /content/drive/MyDrive/Bengali_Taka/Bangla_Paper/Bangladeshi_Paper_Currency_Raw/split/val
